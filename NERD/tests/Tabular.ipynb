# %%
# %load_ext autoreload
# %autoreload 2
# Out:
# The autoreload extension is already loaded. To reload it, use:
#   %reload_ext autoreload

# %%
import sys

# %%
sys.path.append('../../')

# %%
import pandas as pd

# %%
df = pd.read_csv('../datasets/titanic.csv')

# %%
df
# Out:
#      Survived  Pclass                                               Name  \
# 0           0       3                             Mr. Owen Harris Braund
# 1           1       1  Mrs. John Bradley (Florence Briggs Thayer) Cum...
# 2           1       3                              Miss. Laina Heikkinen
# 3           1       1        Mrs. Jacques Heath (Lily May Peel) Futrelle
# 4           0       3                            Mr. William Henry Allen
# ..        ...     ...                                                ...
# 882         0       2                               Rev. Juozas Montvila
# 883         1       1                        Miss. Margaret Edith Graham
# 884         0       3                     Miss. Catherine Helen Johnston
# 885         1       1                               Mr. Karl Howell Behr
# 886         0       3                                 Mr. Patrick Dooley
#
#         Sex   Age  Siblings/Spouses Aboard  Parents/Children Aboard     Fare
# 0      male  22.0                        1                        0   7.2500
# 1    female  38.0                        1                        0  71.2833
# 2    female  26.0                        0                        0   7.9250
# 3    female  35.0                        1                        0  53.1000
# 4      male  35.0                        0                        0   8.0500
# ..      ...   ...                      ...                      ...      ...
# 882    male  27.0                        0                        0  13.0000
# 883  female  19.0                        0                        0  30.0000
# 884  female   7.0                        1                        2  23.4500
# 885    male  26.0                        0                        0  30.0000
# 886    male  32.0                        0                        0   7.7500
#
# [887 rows x 8 columns]

# %%
from NERD.sklearn_extras import MultiLabelEncoder, ColumnsSelector
from sklearn.pipeline import Pipeline

# %%
good_cols = df.columns[1:]

# %%
feat_pipeline = Pipeline([
    ('cols', ColumnsSelector(good_cols)),
    ('feat', MultiLabelEncoder())
])

# %%
unique_tags = [
    ('ALIVE', 'Survived'),
    ('Dead', 'Dead')
]

# %%
from NERD.tabular import DataFrameClassifier

# %%
ts = DataFrameClassifier(df, unique_tags, featurization_pipeline=feat_pipeline, usermanagement=True)
# Out:
# True
# ./nerdusers.json
# ['/load_example', '/update_model', '/save_example', '/save_data', '/', '/static/<path:filename>']

# %%
ts.start_server(port=5052)
# Out:
#  * Serving Flask app "NERD.tabular" (lazy loading)
#  * Environment: production
#    WARNING: This is a development server. Do not use it in a production deployment.
#    Use a production WSGI server instead.
#  * Debug mode: off
# endpoint: base_app, url: http://localhost:5052/, path: /
# endpoint: login, url: http://localhost:5052/login, path: /login
# endpoint: None, url: http://localhost:5052/favicon.ico, path: /favicon.ico
# endpoint: register, url: http://localhost:5052/register, path: /register
# {'username': 'turbo@gmail.com', 'password': 'asdf'}
# endpoint: base_app, url: http://localhost:5052/, path: /
# endpoint: None, url: http://localhost:5052/favicon.ico, path: /favicon.ico
# endpoint: load_example, url: http://localhost:5052/load_example, path: /load_example
# endpoint: save_example, url: http://localhost:5052/save_example, path: /save_example
# ['Dead']
# endpoint: load_example, url: http://localhost:5052/load_example, path: /load_example
# endpoint: save_example, url: http://localhost:5052/save_example, path: /save_example
# ['ALIVE']
# endpoint: load_example, url: http://localhost:5052/load_example, path: /load_example
# endpoint: save_example, url: http://localhost:5052/save_example, path: /save_example
# ['Dead']
# endpoint: update_model, url: http://localhost:5052/update_model, path: /update_model
# endpoint: load_example, url: http://localhost:5052/load_example, path: /load_example
# endpoint: save_example, url: http://localhost:5052/save_example, path: /save_example
# ['Dead']
# endpoint: load_example, url: http://localhost:5052/load_example, path: /load_example
# endpoint: save_example, url: http://localhost:5052/save_example, path: /save_example
# ['Dead']
# endpoint: update_model, url: http://localhost:5052/update_model, path: /update_model
# endpoint: load_example, url: http://localhost:5052/load_example, path: /load_example
# endpoint: save_example, url: http://localhost:5052/save_example, path: /save_example
# ['Dead']
# endpoint: base_app, url: http://localhost:5052/, path: /
# endpoint: load_example, url: http://localhost:5052/load_example, path: /load_example
# endpoint: save_example, url: http://localhost:5052/save_example, path: /save_example
# ['Dead']
# endpoint: load_example, url: http://localhost:5052/load_example, path: /load_example
# endpoint: load_example, url: http://localhost:5052/load_example, path: /load_example
# endpoint: save_example, url: http://localhost:5052/save_example, path: /save_example
# ['Dead']
# endpoint: save_example, url: http://localhost:5052/save_example, path: /save_example
# ['Dead']
# endpoint: update_model, url: http://localhost:5052/update_model, path: /update_model

# %%
ts.um.users
# Out:
# {'deepak@draup.com': {'password': 'asdf'},
#  'turbo@gmail.com': {'password': 'asdf'}}

# %%
df[df['class'].notna()]
# Out:
#      Survived  Pclass                                           Name     Sex  \
# 0           0       3                         Mr. Owen Harris Braund    male
# 3           1       1    Mrs. Jacques Heath (Lily May Peel) Futrelle  female
# 14          0       3            Miss. Hulda Amanda Adolfina Vestrom  female
# 19          1       3                         Mrs. Fatima Masselmani  female
# 22          1       3                             Miss. Anna McGowan  female
# 28          1       3                            Miss. Ellen O'Dwyer  female
# 32          1       3                        Miss. Mary Agatha Glynn  female
# 48          0       3   Mrs. Josef (Josefine Franchi) Arnold-Franchi  female
# 68          0       3                               Mr. Vincenz Kink    male
# 110         0       3                            Miss. Hileni Zabour  female
# 131         0       3  Mrs. Alexander A (Grace Charity Laury) Robins  female
# 144         0       2                    Mr. Joseph Charles Nicholls    male
# 328         1       3                              Miss. Agnes McCoy  female
# 623         0       2                  Rev. Charles Leonard Kirkland    male
# 658         0       3                               Mr. Mohamed Badt    male
# 659         0       1                      Mr. Edward Pomeroy Colley    male
# 699         0       3                           Miss. Saiide Barbara  female
# 724         0       2                 Mr. Kurt Arnold Gottfrid Bryhl    male
# 774         0       3                         Mr. Thomas J Kilgannon    male
# 872         0       3                   Mr. Alfred Ossian Gustafsson    male
#
#       Age  Siblings/Spouses Aboard  Parents/Children Aboard     Fare  class  \
# 0    22.0                        1                        0   7.2500   Dead
# 3    35.0                        1                        0  53.1000  ALIVE
# 14   14.0                        0                        0   7.8542   Dead
# 19   22.0                        0                        0   7.2250  ALIVE
# 22   15.0                        0                        0   8.0292  ALIVE
# 28   24.0                        0                        0   7.8792  ALIVE
# 32   18.0                        0                        0   7.7500  ALIVE
# 48   18.0                        1                        0  17.8000   Dead
# 68   26.0                        2                        0   8.6625   Dead
# 110  14.5                        1                        0  14.4542   Dead
# 131  47.0                        1                        0  14.5000   Dead
# 144  19.0                        1                        1  36.7500   Dead
# 328  28.0                        2                        0  23.2500  ALIVE
# 623  57.0                        0                        0  12.3500   Dead
# 658  40.0                        0                        0   7.2250   Dead
# 659  47.0                        0                        0  25.5875   Dead
# 699  18.0                        0                        1  14.4542   Dead
# 724  25.0                        1                        0  26.0000   Dead
# 774  22.0                        0                        0   7.7375   Dead
# 872  20.0                        0                        0   9.8458   Dead
#
#             NERD_USER
# 0     turbo@gmail.com
# 3    deepak@draup.com
# 14   deepak@draup.com
# 19   deepak@draup.com
# 22   deepak@draup.com
# 28   deepak@draup.com
# 32    turbo@gmail.com
# 48   deepak@draup.com
# 68    turbo@gmail.com
# 110   turbo@gmail.com
# 131   turbo@gmail.com
# 144  deepak@draup.com
# 328               NaN
# 623  deepak@draup.com
# 658  deepak@draup.com
# 659  deepak@draup.com
# 699   turbo@gmail.com
# 724  deepak@draup.com
# 774  deepak@draup.com
# 872   turbo@gmail.com

# %%
ts.save_labelled_examples('DF_Classification_Data/titanic_labelled.json')

# %%
pd.read_json('DF_Classification_Data/titanic_labelled.json', orient='records', lines=True)
# Out:
#      Survived  Pclass                                              Name     Sex    Age  Siblings/Spouses Aboard  Parents/Children Aboard     Fare  class
# 0           0       3                            Mr. Owen Harris Braund    male  22.00                        1                        0   7.2500   Dead
# 1           1       3                             Miss. Laina Heikkinen  female  26.00                        0                        0   7.9250  ALIVE
# 2           1       3  Mrs. Oscar W (Elisabeth Vilhelmina Berg) Johnson  female  27.00                        0                        2  11.1333  ALIVE
# 3           1       3                    Miss. Marguerite Rut Sandstrom  female   4.00                        1                        1  16.7000  ALIVE
# 4           0       3                               Master. Eugene Rice    male   2.00                        4                        1  29.1250   Dead
# ..        ...     ...                                               ...     ...    ...                      ...                      ...      ...    ...
# 153         1       2                              Master. Andre Mallet    male   1.00                        0                        2  37.0042  ALIVE
# 154         1       2                    Master. George Sibley Richards    male   0.83                        1                        1  18.7500  ALIVE
# 155         0       3                         Mr. Peter L Lemberopolous    male  34.50                        0                        0   6.4375   Dead
# 156         0       3                                Mr. Jeso Culumovic    male  17.00                        0                        0   8.6625   Dead
# 157         0       3                            Miss. Nourelain Boulos  female   9.00                        1                        1  15.2458   Dead
#
# [158 rows x 9 columns]
