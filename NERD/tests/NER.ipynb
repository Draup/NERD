# %%
# %load_ext autoreload
# %autoreload 2

# %%
import sys

# %%
sys.path.append('../../')

# %%
import pandas as pd

# %%
df = pd.read_json('../datasets/NER_DATASET.json', lines=True)

# %%
annotations = set()

# %%
for ann in df.annotation:
    for item in ann:
        label = item['label']
        annotations.update(label)

# %%
annotations
# Out:
# {'College Name',
#  'Companies worked at',
#  'Degree',
#  'Designation',
#  'Email Address',
#  'Graduation Year',
#  'Location',
#  'Name',
#  'Skills',
#  'UNKNOWN',
#  'Years of Experience'}

# %%
tag_data = [(i.replace(' ', ''), i) for i in annotations]

# %%
sents = df.content

# %%
all_sents = []
for sent in sents[:5]:
    all_sents.extend(sent.split('\n'))

all_sents = [s for s in all_sents if len(s) > 0]

# %%
len(all_sents)
# Out:
# 358

# %%
from NERD.ner import NerTagger

# %%
nertagger = NerTagger(all_sents, tag_data)

# %%
nertagger.ntagger.dataset
# Out:
# [{'status': 'UNLABELLED',
#   'data': {'raw': [('Abhishek', 'NNP'), ('Jha', 'NNP')]}},
#  {'status': 'UNLABELLED',
#   'data': {'raw': [('Application', 'NNP'),
#     ('Development', 'NNP'),
#     ('Associate', 'NNP'),
#     ('-', ':'),
#     ('Accenture', 'NN')]}},
#  {'status': 'UNLABELLED',
#   'data': {'raw': [('Bengaluru', 'NNP'),
#     (',', ','),
#     ('Karnataka', 'NNP'),
#     ('-', ':'),
#     ('Email', 'NNP'),
#     ('me', 'PRP'),
#     ('on', 'IN'),
#     ('Indeed', 'RB'),
#     (':', ':'),
#     ('indeed.com/r/Abhishek-Jha/10e7a8cb732bc43a', 'NN')]}},
#  {'status': 'UNLABELLED',
#   'data': {'raw': [('•', 'NN'),
#     ('To', 'TO'),
#     ('work', 'VB'),
#     ('for', 'IN'),
#     ('an', 'DT'),
#     ('organization', 'NN'),
#     ('which', 'WDT'),
#     ('provides', 'VBZ'),
#     ('me', 'PRP'),
#     ('the', 'DT'),
#     ('opportunity', 'NN'),
#     ('to', 'TO'),
#     ('improve', 'VB'),
#     ('my', 'PRP$'),
#     ('skills', 'NNS')]}},
#  {'status': 'UNLABELLED',
#   'data': {'raw': [('and', 'CC'),
#     ('knowledge', 'NN'),
#     ('for', 'IN'),
#     ('my', 'PRP$'),
#     ('individual', 'JJ'),
#     ('and', 'CC'),
#     ('company', 'NN'),
#     ("'s", 'POS'),
#     ('growth', 'NN'),
#     ('in', 'IN'),
#     ('best', 'JJS'),
#     ('possible', 'JJ'),
#     ('ways', 'NNS'),
#     ('.', '.')]}},
#  {'status': 'UNLABELLED',
#   'data': {'raw': [('Willing', 'VBG'),
#     ('to', 'TO'),
#     ('relocate', 'VB'),
#     ('to', 'TO'),
#     (':', ':'),
#     ('Bangalore', 'NNP'),
#     (',', ','),
#     ('Karnataka', 'NNP')]}},
#  {'status': 'UNLABELLED',
#   'data': {'raw': [('WORK', 'NN'), ('EXPERIENCE', 'NN')]}},
#  {'status': 'UNLABELLED',
#   'data': {'raw': [('Application', 'NNP'),
#     ('Development', 'NNP'),
#     ('Associate', 'NNP')]}},
#  {'status': 'UNLABELLED', 'data': {'raw': [('Accenture', 'NNP'), ('-', ':')]}},
#  {'status': 'UNLABELLED',
#   'data': {'raw': [('November', 'NNP'),
#     ('2017', 'CD'),
#     ('to', 'TO'),
#     ('Present', 'VB')]}},
#  {'status': 'UNLABELLED',
#   'data': {'raw': [('Role', 'NN'),
#     (':', ':'),
#     ('Currently', 'RB'),
#     ('working', 'VBG'),
#     ('on', 'IN'),
#     ('Chat-bot', 'NNP'),
#     ('.', '.'),
#     ('Developing', 'VBG'),
#     ('Backend', 'NNP'),
#     ('Oracle', 'NNP'),
#     ('PeopleSoft', 'NNP'),
#     ('Queries', 'NNS')]}},
#  {'status': 'UNLABELLED',
#   'data': {'raw': [('for', 'IN'),
#     ('the', 'DT'),
#     ('Bot', 'NNP'),
#     ('which', 'WDT'),
#     ('will', 'MD'),
#     ('be', 'VB'),
#     ('triggered', 'VBN'),
#     ('based', 'VBN'),
#     ('on', 'IN'),
#     ('given', 'VBN'),
#     ('input', 'NN'),
#     ('.', '.'),
#     ('Also', 'RB'),
#     (',', ','),
#     ('Training', 'VBG'),
#     ('the', 'DT'),
#     ('bot', 'NN'),
#     ('for', 'IN'),
#     ('different', 'JJ'),
#     ('possible', 'JJ')]}},
#  {'status': 'UNLABELLED',
#   'data': {'raw': [('utterances', 'NNS'),
#     ('(', '('),
#     ('Both', 'DT'),
#     ('positive', 'JJ'),
#     ('and', 'CC'),
#     ('negative', 'JJ'),
#     (')', ')'),
#     (',', ','),
#     ('which', 'WDT'),
#     ('will', 'MD'),
#     ('be', 'VB'),
#     ('given', 'VBN'),
#     ('as', 'IN')]}},
#  {'status': 'UNLABELLED',
#   'data': {'raw': [('input', 'NN'),
#     ('by', 'IN'),
#     ('the', 'DT'),
#     ('user', 'NN'),
#     ('.', '.')]}},
#  {'status': 'UNLABELLED', 'data': {'raw': [('EDUCATION', 'NN')]}},
#  {'status': 'UNLABELLED',
#   'data': {'raw': [('B.E', 'NNP'),
#     ('in', 'IN'),
#     ('Information', 'NNP'),
#     ('science', 'NN'),
#     ('and', 'CC'),
#     ('engineering', 'NN')]}},
#  {'status': 'UNLABELLED',
#   'data': {'raw': [('B.v.b', 'NNP'),
#     ('college', 'NN'),
#     ('of', 'IN'),
#     ('engineering', 'NN'),
#     ('and', 'CC'),
#     ('technology', 'NN'),
#     ('-', ':'),
#     ('Hubli', 'NNP'),
#     (',', ','),
#     ('Karnataka', 'NNP')]}},
#  {'status': 'UNLABELLED',
#   'data': {'raw': [('August', 'NNP'),
#     ('2013', 'CD'),
#     ('to', 'TO'),
#     ('June', 'NNP'),
#     ('2017', 'CD')]}},
#  {'status': 'UNLABELLED',
#   'data': {'raw': [('12th', 'CD'), ('in', 'IN'), ('Mathematics', 'NNS')]}},
#  {'status': 'UNLABELLED',
#   'data': {'raw': [('Woodbine', 'NNP'), ('modern', 'JJ'), ('school', 'NN')]}},
#  {'status': 'UNLABELLED',
#   'data': {'raw': [('April', 'NNP'),
#     ('2011', 'CD'),
#     ('to', 'TO'),
#     ('March', 'NNP'),
#     ('2013', 'CD')]}},
#  {'status': 'UNLABELLED', 'data': {'raw': [('10th', 'NNS')]}},
#  {'status': 'UNLABELLED',
#   'data': {'raw': [('Kendriya', 'NNP'), ('Vidyalaya', 'NNP')]}},
#  {'status': 'UNLABELLED',
#   'data': {'raw': [('April', 'NNP'),
#     ('2001', 'CD'),
#     ('to', 'TO'),
#     ('March', 'NNP'),
#     ('2011', 'CD')]}},
#  {'status': 'UNLABELLED', 'data': {'raw': [('SKILLS', 'NN')]}},
#  {'status': 'UNLABELLED',
#   'data': {'raw': [('C', 'NNP'),
#     ('(', '('),
#     ('Less', 'NNP'),
#     ('than', 'IN'),
#     ('1', 'CD'),
#     ('year', 'NN'),
#     (')', ')'),
#     (',', ','),
#     ('Database', 'NNP'),
#     ('(', '('),
#     ('Less', 'NNP'),
#     ('than', 'IN'),
#     ('1', 'CD'),
#     ('year', 'NN'),
#     (')', ')'),
#     (',', ','),
#     ('Database', 'NNP'),
#     ('Management', 'NNP'),
#     ('(', '('),
#     ('Less', 'NNP'),
#     ('than', 'IN'),
#     ('1', 'CD'),
#     ('year', 'NN'),
#     (')', ')'),
#     (',', ',')]}},
#  {'status': 'UNLABELLED',
#   'data': {'raw': [('Database', 'NNP'),
#     ('Management', 'NNP'),
#     ('System', 'NNP'),
#     ('(', '('),
#     ('Less', 'NNP'),
#     ('than', 'IN'),
#     ('1', 'CD'),
#     ('year', 'NN'),
#     (')', ')'),
#     (',', ','),
#     ('Java', 'NNP'),
#     ('(', '('),
#     ('Less', 'NNP'),
#     ('than', 'IN'),
#     ('1', 'CD'),
#     ('year', 'NN'),
#     (')', ')')]}},
#  {'status': 'UNLABELLED',
#   'data': {'raw': [('ADDITIONAL', 'DT'), ('INFORMATION', 'NN')]}},
#  {'status': 'UNLABELLED',
#   'data': {'raw': [('Technical', 'JJ'), ('Skills', 'NNS')]}},
#  {'status': 'UNLABELLED',
#   'data': {'raw': [('https', 'NN'),
#     (':', ':'),
#     ('//www.indeed.com/r/Abhishek-Jha/10e7a8cb732bc43a', 'JJ'),
#     ('?', '.'),
#     ('isid=rex-download', 'JJ'),
#     ('&', 'CC'),
#     ('ikw=download-top', 'JJ'),
#     ('&', 'CC'),
#     ('co=IN', 'NN')]}},
#  {'status': 'UNLABELLED',
#   'data': {'raw': [('•', 'NN'),
#     ('Programming', 'VBG'),
#     ('language', 'NN'),
#     (':', ':'),
#     ('C', 'NNP'),
#     (',', ','),
#     ('C++', 'NNP'),
#     (',', ','),
#     ('Java', 'NNP')]}},
#  {'status': 'UNLABELLED',
#   'data': {'raw': [('•', 'JJ'), ('Oracle', 'NNP'), ('PeopleSoft', 'NNP')]}},
#  {'status': 'UNLABELLED',
#   'data': {'raw': [('•', 'JJ'),
#     ('Internet', 'NNP'),
#     ('Of', 'IN'),
#     ('Things', 'NNP')]}},
#  {'status': 'UNLABELLED',
#   'data': {'raw': [('•', 'JJ'), ('Machine', 'NNP'), ('Learning', 'NNP')]}},
#  {'status': 'UNLABELLED',
#   'data': {'raw': [('•', 'JJ'),
#     ('Database', 'NNP'),
#     ('Management', 'NNP'),
#     ('System', 'NNP')]}},
#  {'status': 'UNLABELLED',
#   'data': {'raw': [('•', 'JJ'), ('Computer', 'NNP'), ('Networks', 'NNP')]}},
#  {'status': 'UNLABELLED',
#   'data': {'raw': [('•', 'NN'),
#     ('Operating', 'VBG'),
#     ('System', 'NNP'),
#     ('worked', 'VBD'),
#     ('on', 'IN'),
#     (':', ':'),
#     ('Linux', 'NNP'),
#     (',', ','),
#     ('Windows', 'NNP'),
#     (',', ','),
#     ('Mac', 'NNP')]}},
#  {'status': 'UNLABELLED',
#   'data': {'raw': [('Non', 'NNP'),
#     ('-', ':'),
#     ('Technical', 'JJ'),
#     ('Skills', 'NNS')]}},
#  {'status': 'UNLABELLED',
#   'data': {'raw': [('•', 'JJ'),
#     ('Honest', 'NNP'),
#     ('and', 'CC'),
#     ('Hard-Working', 'NNP')]}},
#  {'status': 'UNLABELLED',
#   'data': {'raw': [('•', 'NN'),
#     ('Tolerant', 'NNP'),
#     ('and', 'CC'),
#     ('Flexible', 'NNP'),
#     ('to', 'TO'),
#     ('Different', 'NNP'),
#     ('Situations', 'NNP')]}},
#  {'status': 'UNLABELLED',
#   'data': {'raw': [('•', 'JJ'),
#     ('Polite', 'NNP'),
#     ('and', 'CC'),
#     ('Calm', 'NNP')]}},
#  {'status': 'UNLABELLED',
#   'data': {'raw': [('•', 'CD'), ('Team-Player', 'NN')]}},
#  {'status': 'UNLABELLED',
#   'data': {'raw': [('Afreen', 'NNP'), ('Jamadar', 'NNP')]}},
#  {'status': 'UNLABELLED',
#   'data': {'raw': [('Active', 'JJ'),
#     ('member', 'NN'),
#     ('of', 'IN'),
#     ('IIIT', 'NNP'),
#     ('Committee', 'NNP'),
#     ('in', 'IN'),
#     ('Third', 'NNP'),
#     ('year', 'NN')]}},
#  {'status': 'UNLABELLED',
#   'data': {'raw': [('Sangli', 'NNP'),
#     (',', ','),
#     ('Maharashtra', 'NNP'),
#     ('-', ':'),
#     ('Email', 'NNP'),
#     ('me', 'PRP'),
#     ('on', 'IN'),
#     ('Indeed', 'RB'),
#     (':', ':'),
#     ('indeed.com/r/Afreen-Jamadar/8baf379b705e37c6', 'NN')]}},
#  {'status': 'UNLABELLED',
#   'data': {'raw': [('I', 'PRP'),
#     ('wish', 'VBP'),
#     ('to', 'TO'),
#     ('use', 'VB'),
#     ('my', 'PRP$'),
#     ('knowledge', 'NN'),
#     (',', ','),
#     ('skills', 'NNS'),
#     ('and', 'CC'),
#     ('conceptual', 'JJ'),
#     ('understanding', 'NN'),
#     ('to', 'TO'),
#     ('create', 'VB'),
#     ('excellent', 'JJ'),
#     ('team', 'NN')]}},
#  {'status': 'UNLABELLED',
#   'data': {'raw': [('environments', 'NNS'),
#     ('and', 'CC'),
#     ('work', 'NN'),
#     ('consistently', 'RB'),
#     ('achieving', 'VBG'),
#     ('organization', 'NN'),
#     ('objectives', 'NNS'),
#     ('believes', 'VBZ'),
#     ('in', 'IN'),
#     ('taking', 'VBG'),
#     ('initiative', 'JJ')]}},
#  {'status': 'UNLABELLED',
#   'data': {'raw': [('and', 'CC'),
#     ('work', 'NN'),
#     ('to', 'TO'),
#     ('excellence', 'VB'),
#     ('in', 'IN'),
#     ('my', 'PRP$'),
#     ('work', 'NN'),
#     ('.', '.')]}},
#  {'status': 'UNLABELLED',
#   'data': {'raw': [('WORK', 'NN'), ('EXPERIENCE', 'NN')]}},
#  {'status': 'UNLABELLED',
#   'data': {'raw': [('Active', 'JJ'),
#     ('member', 'NN'),
#     ('of', 'IN'),
#     ('IIIT', 'NNP'),
#     ('Committee', 'NNP'),
#     ('in', 'IN'),
#     ('Third', 'NNP'),
#     ('year', 'NN')]}},
#  {'status': 'UNLABELLED',
#   'data': {'raw': [('Cisco', 'NNP'),
#     ('Networking', 'NNP'),
#     ('-', ':'),
#     ('Kanpur', 'NNP'),
#     (',', ','),
#     ('Uttar', 'NNP'),
#     ('Pradesh', 'NNP')]}},
#  {'status': 'UNLABELLED',
#   'data': {'raw': [('organized', 'VBN'),
#     ('by', 'IN'),
#     ('Techkriti', 'NNP'),
#     ('IIT', 'NNP'),
#     ('Kanpur', 'NNP'),
#     ('and', 'CC'),
#     ('Azure', 'NNP'),
#     ('Skynet', 'NNP'),
#     ('.', '.')]}},
#  {'status': 'UNLABELLED',
#   'data': {'raw': [('PERSONALLITY', 'NNP'), ('TRAITS', 'NNP'), (':', ':')]}},
#  {'status': 'UNLABELLED',
#   'data': {'raw': [('•', 'NN'),
#     ('Quick', 'NNP'),
#     ('learning', 'NN'),
#     ('ability', 'NN')]}},
#  {'status': 'UNLABELLED',
#   'data': {'raw': [('•', 'RB'), ('hard', 'JJ'), ('working', 'VBG')]}},
#  {'status': 'UNLABELLED', 'data': {'raw': [('EDUCATION', 'NN')]}},
#  {'status': 'UNLABELLED', 'data': {'raw': [('PG-DAC', 'NN')]}},
#  {'status': 'UNLABELLED', 'data': {'raw': [('CDAC', 'NNP'), ('ACTS', 'NNP')]}},
#  {'status': 'UNLABELLED', 'data': {'raw': [('2017', 'CD')]}},
#  {'status': 'UNLABELLED',
#   'data': {'raw': [('Bachelor', 'NNP'),
#     ('of', 'IN'),
#     ('Engg', 'NNP'),
#     ('in', 'IN'),
#     ('Information', 'NNP'),
#     ('Technology', 'NNP')]}},
#  {'status': 'UNLABELLED',
#   'data': {'raw': [('Shivaji', 'NNP'),
#     ('University', 'NNP'),
#     ('Kolhapur', 'NNP'),
#     ('-', ':'),
#     ('Kolhapur', 'NNP'),
#     (',', ','),
#     ('Maharashtra', 'NNP')]}},
#  {'status': 'UNLABELLED', 'data': {'raw': [('2016', 'CD')]}},
#  {'status': 'UNLABELLED', 'data': {'raw': [('SKILLS', 'NN')]}},
#  {'status': 'UNLABELLED',
#   'data': {'raw': [('Database', 'NNP'),
#     ('(', '('),
#     ('Less', 'NNP'),
#     ('than', 'IN'),
#     ('1', 'CD'),
#     ('year', 'NN'),
#     (')', ')'),
#     (',', ','),
#     ('HTML', 'NNP'),
#     ('(', '('),
#     ('Less', 'NNP'),
#     ('than', 'IN'),
#     ('1', 'CD'),
#     ('year', 'NN'),
#     (')', ')'),
#     (',', ','),
#     ('Linux', 'NNP'),
#     ('.', '.'),
#     ('(', '('),
#     ('Less', 'JJR'),
#     ('than', 'IN'),
#     ('1', 'CD'),
#     ('year', 'NN'),
#     (')', ')'),
#     (',', ','),
#     ('MICROSOFT', 'NNP')]}},
#  {'status': 'UNLABELLED',
#   'data': {'raw': [('ACCESS', 'NNP'),
#     ('(', '('),
#     ('Less', 'NNP'),
#     ('than', 'IN'),
#     ('1', 'CD'),
#     ('year', 'NN'),
#     (')', ')'),
#     (',', ','),
#     ('MICROSOFT', 'NNP'),
#     ('WINDOWS', 'NNP'),
#     ('(', '('),
#     ('Less', 'NNP'),
#     ('than', 'IN'),
#     ('1', 'CD'),
#     ('year', 'NN'),
#     (')', ')')]}},
#  {'status': 'UNLABELLED',
#   'data': {'raw': [('ADDITIONAL', 'DT'), ('INFORMATION', 'NN')]}},
#  {'status': 'UNLABELLED',
#   'data': {'raw': [('TECHNICAL', 'NNP'), ('SKILLS', 'NNP'), (':', ':')]}},
#  {'status': 'UNLABELLED',
#   'data': {'raw': [('•', 'NN'),
#     ('Programming', 'VBG'),
#     ('Languages', 'NNS'),
#     (':', ':'),
#     ('C', 'NNP'),
#     (',', ','),
#     ('C++', 'NNP'),
#     (',', ','),
#     ('Java', 'NNP'),
#     (',', ','),
#     ('.net', 'NNP'),
#     (',', ','),
#     ('php', 'NN'),
#     ('.', '.')]}},
#  {'status': 'UNLABELLED',
#   'data': {'raw': [('•', 'JJ'),
#     ('Web', 'NNP'),
#     ('Designing', 'NNP'),
#     (':', ':'),
#     ('HTML', 'NNP'),
#     (',', ','),
#     ('XML', 'NNP')]}},
#  {'status': 'UNLABELLED',
#   'data': {'raw': [('•', 'NN'),
#     ('Operating', 'VBG'),
#     ('Systems', 'NNPS'),
#     (':', ':'),
#     ('Windows', 'NNP'),
#     ('[', 'NNP'),
#     ('…', 'NNP'),
#     (']', 'NNP'),
#     ('Windows', 'NNP'),
#     ('Server', 'NNP'),
#     ('2003', 'CD'),
#     (',', ','),
#     ('Linux', 'NNP'),
#     ('.', '.')]}},
#  {'status': 'UNLABELLED',
#   'data': {'raw': [('•', 'JJ'),
#     ('Database', 'NNP'),
#     (':', ':'),
#     ('MS', 'NNP'),
#     ('Access', 'NNP'),
#     (',', ','),
#     ('MS', 'NNP'),
#     ('SQL', 'NNP'),
#     ('Server', 'NNP'),
#     ('2008', 'CD'),
#     (',', ','),
#     ('Oracle', 'NNP'),
#     ('10g', 'CD'),
#     (',', ','),
#     ('MySql', 'NNP'),
#     ('.', '.')]}},
#  {'status': 'UNLABELLED',
#   'data': {'raw': [('https', 'NN'),
#     (':', ':'),
#     ('//www.indeed.com/r/Afreen-Jamadar/8baf379b705e37c6', 'JJ'),
#     ('?', '.'),
#     ('isid=rex-download', 'JJ'),
#     ('&', 'CC'),
#     ('ikw=download-top', 'JJ'),
#     ('&', 'CC'),
#     ('co=IN', 'NN')]}},
#  {'status': 'UNLABELLED',
#   'data': {'raw': [('Akhil', 'NNP'), ('Yadav', 'NNP'), ('Polemaina', 'NNP')]}},
#  {'status': 'UNLABELLED',
#   'data': {'raw': [('Hyderabad', 'NNP'),
#     (',', ','),
#     ('Telangana', 'NNP'),
#     ('-', ':'),
#     ('Email', 'NNP'),
#     ('me', 'PRP'),
#     ('on', 'IN'),
#     ('Indeed', 'RB'),
#     (':', ':'),
#     ('indeed.com/r/Akhil-Yadav-Polemaina/', 'NN')]}},
#  {'status': 'UNLABELLED', 'data': {'raw': [('f6931801c51c63b1', 'NN')]}},
#  {'status': 'UNLABELLED',
#   'data': {'raw': [('●', 'RB'),
#     ('Senior', 'NNP'),
#     ('System', 'NNP'),
#     ('Engineer', 'NNP'),
#     ('at', 'IN'),
#     ('Infosys', 'NNP'),
#     ('with', 'IN'),
#     ('3.2', 'CD'),
#     ('years', 'NNS'),
#     ('of', 'IN'),
#     ('experience', 'NN'),
#     ('in', 'IN'),
#     ('software', 'NN'),
#     ('development', 'NN'),
#     ('and', 'CC')]}},
#  {'status': 'UNLABELLED',
#   'data': {'raw': [('Maintenance', 'NN'), ('.', '.')]}},
#  {'status': 'UNLABELLED',
#   'data': {'raw': [('●', 'NN'),
#     ('Maintained', 'VBD'),
#     ('data', 'NNS'),
#     ('processing', 'VBG'),
#     ('using', 'VBG'),
#     ('mainframe', 'NN'),
#     ('technology', 'NN'),
#     ('for', 'IN'),
#     ('multiple', 'JJ'),
#     ('front', 'JJ'),
#     ('end', 'NN'),
#     ('applications', 'NNS'),
#     ('of', 'IN')]}},
#  {'status': 'UNLABELLED',
#   'data': {'raw': [('Walmart', 'NNP'),
#     ('Retail', 'NNP'),
#     ('Link', 'NNP'),
#     ('platform', 'NN'),
#     ('and', 'CC'),
#     ('ensured', 'VBD'),
#     ('on-time', 'JJ'),
#     ('deliverables', 'NNS'),
#     ('.', '.')]}},
#  {'status': 'UNLABELLED',
#   'data': {'raw': [('●', 'NN'),
#     ('Worked', 'VBD'),
#     ('on', 'IN'),
#     ('automating', 'VBG'),
#     ('the', 'DT'),
#     ('uses', 'NNS'),
#     ('cases', 'NNS'),
#     ('to', 'TO'),
#     ('reduce', 'VB'),
#     ('manual', 'JJ'),
#     ('effort', 'NN'),
#     ('in', 'IN'),
#     ('solving', 'VBG'),
#     ('repeating', 'VBG'),
#     ('incidents', 'NNS')]}},
#  {'status': 'UNLABELLED',
#   'data': {'raw': [('using', 'VBG'),
#     ('Service', 'NNP'),
#     ('Now', 'RB'),
#     ('orchestration', 'NN'),
#     ('.', '.')]}},
#  {'status': 'UNLABELLED',
#   'data': {'raw': [('●', 'JJ'),
#     ('Possess', 'NNP'),
#     ('good', 'JJ'),
#     ('analytical', 'JJ'),
#     (',', ','),
#     ('logical', 'JJ'),
#     ('ability', 'NN'),
#     ('and', 'CC'),
#     ('systematic', 'JJ'),
#     ('approach', 'NN'),
#     ('to', 'TO'),
#     ('problem', 'NN'),
#     ('analysis', 'NN'),
#     (',', ','),
#     ('strong', 'JJ')]}},
#  {'status': 'UNLABELLED',
#   'data': {'raw': [('debugging', 'NN'),
#     ('and', 'CC'),
#     ('troubleshooting', 'VBG'),
#     ('skills', 'NNS'),
#     ('.', '.')]}},
#  {'status': 'UNLABELLED',
#   'data': {'raw': [('●', 'RB'),
#     ('Good', 'JJ'),
#     ('exposure', 'NN'),
#     ('to', 'TO'),
#     ('Retail', 'NNP'),
#     ('domain', 'NN'),
#     ('.', '.')]}},
#  {'status': 'UNLABELLED',
#   'data': {'raw': [('Willing', 'VBG'),
#     ('to', 'TO'),
#     ('relocate', 'VB'),
#     ('to', 'TO'),
#     (':', ':'),
#     ('hyderbad', 'NN'),
#     (',', ','),
#     ('Telangana', 'NNP')]}},
#  {'status': 'UNLABELLED',
#   'data': {'raw': [('WORK', 'NN'), ('EXPERIENCE', 'NN')]}},
#  {'status': 'UNLABELLED',
#   'data': {'raw': [('Senior', 'JJ'),
#     ('Systems', 'NNP'),
#     ('Engineer', 'NNP')]}},
#  {'status': 'UNLABELLED',
#   'data': {'raw': [('Infosys', 'NNP'),
#     ('Limited', 'NNP'),
#     ('-', ':'),
#     ('Hyderabad', 'NNP'),
#     (',', ','),
#     ('Telangana', 'NNP'),
#     ('-', ':')]}},
#  {'status': 'UNLABELLED',
#   'data': {'raw': [('January', 'NNP'),
#     ('2015', 'CD'),
#     ('to', 'TO'),
#     ('Present', 'VB')]}},
#  {'status': 'UNLABELLED',
#   'data': {'raw': [('●', 'JJ'),
#     ('Working', 'VBG'),
#     ('on', 'IN'),
#     ('all', 'PDT'),
#     ('the', 'DT'),
#     ('Major', 'NNP'),
#     ('and', 'CC'),
#     ('Minor', 'NNP'),
#     ('Enhancement', 'NNP'),
#     ('requests', 'NNS'),
#     ('as', 'IN'),
#     ('part', 'NN'),
#     ('of', 'IN'),
#     ('Maintenance', 'NNP'),
#     ('and', 'CC'),
#     ('Support', 'NNP')]}},
#  {'status': 'UNLABELLED', 'data': {'raw': [('activities', 'NNS')]}},
#  {'status': 'UNLABELLED',
#   'data': {'raw': [('●', 'NN'),
#     ('Identifying', 'NNP'),
#     ('and', 'CC'),
#     ('fixing', 'VBG'),
#     ('all', 'PDT'),
#     ('the', 'DT'),
#     ('major', 'JJ'),
#     ('defects', 'NNS'),
#     ('in', 'IN'),
#     ('the', 'DT'),
#     ('applications', 'NNS'),
#     (',', ','),
#     ('perform', 'VB'),
#     ('root', 'NN'),
#     ('cause', 'NN'),
#     ('analysis', 'NN'),
#     ('for', 'IN')]}},
#  {'status': 'UNLABELLED',
#   'data': {'raw': [('production', 'NN'), ('issues', 'NNS')]}},
#  {'status': 'UNLABELLED',
#   'data': {'raw': [('●', 'NN'),
#     ('Being', 'VBG'),
#     ('a', 'DT'),
#     ('subject', 'NN'),
#     ('matter', 'NN'),
#     ('expert', 'NN'),
#     (',', ','),
#     ('involved', 'VBN'),
#     ('in', 'IN'),
#     ('multiple', 'JJ'),
#     ('Knowledge', 'NNP'),
#     ('transfer', 'NN'),
#     ('and', 'CC'),
#     ('knowledge', 'NN'),
#     ('sharing', 'NN')]}},
#  {'status': 'UNLABELLED',
#   'data': {'raw': [('sessions', 'NNS'),
#     ('with', 'IN'),
#     ('the', 'DT'),
#     ('client', 'NN')]}},
#  {'status': 'UNLABELLED',
#   'data': {'raw': [('●', 'NN'),
#     ('Leading', 'VBG'),
#     ('a', 'DT'),
#     ('peer', 'NN'),
#     ('group', 'NN'),
#     ('and', 'CC'),
#     ('taking', 'VBG'),
#     ('end', 'NN'),
#     ('to', 'TO'),
#     ('end', 'VB'),
#     ('responsibilities', 'NNS'),
#     ('for', 'IN'),
#     ('all', 'PDT'),
#     ('the', 'DT'),
#     ('critical', 'JJ'),
#     ('issues/', 'NN')]}},
#  {'status': 'UNLABELLED',
#   'data': {'raw': [('enhancements', 'NNS'), ('.', '.')]}},
#  {'status': 'UNLABELLED',
#   'data': {'raw': [('●', 'NN'),
#     ('Identifying', 'VBG'),
#     ('the', 'DT'),
#     ('use', 'NN'),
#     ('cases', 'NNS'),
#     ('which', 'WDT'),
#     ('can', 'MD'),
#     ('be', 'VB'),
#     ('automated', 'VBN'),
#     ('using', 'VBG'),
#     ('Service', 'NNP'),
#     ('Now', 'RB'),
#     ('Orchestration', 'NNP')]}},
#  {'status': 'UNLABELLED',
#   'data': {'raw': [('●', 'NN'),
#     ('Creating', 'VBG'),
#     ('workflows', 'NNS'),
#     ('to', 'TO'),
#     ('automate', 'VB'),
#     ('various', 'JJ'),
#     ('tasks', 'NNS'),
#     ('which', 'WDT'),
#     ('involved', 'VBD'),
#     ('manual', 'JJ'),
#     ('intervention', 'NN')]}},
#  {'status': 'UNLABELLED',
#   'data': {'raw': [('●', 'NNS'),
#     ('Direct', 'JJ'),
#     ('interaction', 'NN'),
#     ('with', 'IN'),
#     ('the', 'DT'),
#     ('client', 'NN'),
#     ('on', 'IN'),
#     ('various', 'JJ'),
#     ('business', 'NN'),
#     ('impacting', 'VBG'),
#     ('issues', 'NNS'),
#     ('on', 'IN'),
#     ('a', 'DT'),
#     ('daily', 'JJ'),
#     ('basis', 'NN')]}},
#  {'status': 'UNLABELLED',
#   'data': {'raw': [('●', 'NN'),
#     ('Setting', 'VBG'),
#     ('up', 'RP'),
#     ('Weekly', 'JJ'),
#     ('Status', 'NNP'),
#     ('Review', 'NNP'),
#     ('meetings', 'NNS'),
#     ('and', 'CC'),
#     ('Code', 'NNP'),
#     ('Review', 'NNP'),
#     ('meetings', 'NNS'),
#     ('with', 'IN'),
#     ('the', 'DT'),
#     ('client', 'NN')]}},
#  {'status': 'UNLABELLED',
#   'data': {'raw': [('Senior', 'JJ'),
#     ('Systems', 'NNP'),
#     ('Engineer', 'NNP')]}},
#  {'status': 'UNLABELLED',
#   'data': {'raw': [('Infosys', 'NNP'),
#     ('Limited', 'NNP'),
#     ('-', ':'),
#     ('Hyderabad', 'NNP'),
#     (',', ','),
#     ('Telangana', 'NNP'),
#     ('-', ':')]}},
#  {'status': 'UNLABELLED',
#   'data': {'raw': [('January', 'NNP'),
#     ('2015', 'CD'),
#     ('to', 'TO'),
#     ('Present', 'VB')]}},
#  {'status': 'UNLABELLED',
#   'data': {'raw': [('Team', 'NNP'),
#     ('Size', 'NNP'),
#     ('#', '#'),
#     ('5', 'CD')]}},
#  {'status': 'UNLABELLED',
#   'data': {'raw': [('Project', 'NN'), ('Objective', 'CD'), (':', ':')]}},
#  {'status': 'UNLABELLED',
#   'data': {'raw': [('Providing', 'VBG'),
#     ('end', 'NN'),
#     ('to', 'TO'),
#     ('end', 'VB'),
#     ('Maintenance', 'NN'),
#     ('and', 'CC'),
#     ('Support', 'NNP'),
#     ('activity', 'NN'),
#     ('for', 'IN'),
#     ('data', 'NNS'),
#     ('processing', 'NN'),
#     ('of', 'IN'),
#     ('the', 'DT'),
#     ('most', 'RBS'),
#     ('critical', 'JJ'),
#     ('and', 'CC')]}},
#  {'status': 'UNLABELLED',
#   'data': {'raw': [('important', 'JJ'),
#     ('Web', 'NNP'),
#     ('portal', 'JJ'),
#     ("'Retail", 'POS'),
#     ('Link', 'NNP'),
#     ("'", 'POS'),
#     ('along', 'IN'),
#     ('with', 'IN'),
#     ('over', 'IN'),
#     ('40', 'CD'),
#     ('applications', 'NNS'),
#     ('used', 'VBN'),
#     ('daily', 'RB'),
#     ('by', 'IN'),
#     ('all', 'PDT'),
#     ('the', 'DT'),
#     ('Suppliers', 'NNS')]}},
#  {'status': 'UNLABELLED',
#   'data': {'raw': [('and', 'CC'),
#     ('Business', 'NNP'),
#     ('users', 'NNS'),
#     ('of', 'IN'),
#     ('Walmart', 'NNP'),
#     (',', ','),
#     ('the', 'DT'),
#     ('largest', 'JJS'),
#     ('retailer', 'NN'),
#     ('in', 'IN'),
#     ('the', 'DT'),
#     ('world', 'NN'),
#     ('.', '.'),
#     ('Retail', 'JJ'),
#     ('link', 'NN'),
#     ('is', 'VBZ'),
#     ('a', 'DT'),
#     ('portal', 'JJ'),
#     ('which', 'WDT'),
#     ('hosts', 'NNS')]}},
#  {'status': 'UNLABELLED',
#   'data': {'raw': [('100', 'CD'),
#     ("'s", 'POS'),
#     ('of', 'IN'),
#     ('applications', 'NNS'),
#     ('developed', 'VBN'),
#     ('across', 'IN'),
#     ('technologies', 'NNS'),
#     ('for', 'IN'),
#     ('the', 'DT'),
#     ('suppliers', 'NNS'),
#     ('which', 'WDT'),
#     ('help', 'VBP'),
#     ('them', 'PRP'),
#     ('to', 'TO'),
#     ('carry', 'VB')]}},
#  {'status': 'UNLABELLED',
#   'data': {'raw': [('on', 'IN'),
#     ('day-to-day', 'JJ'),
#     ('activities', 'NNS'),
#     ('right', 'RB'),
#     ('from', 'IN'),
#     ('on', 'IN'),
#     ('boarding', 'VBG'),
#     ('to', 'TO'),
#     ('tracking', 'VBG'),
#     ('their', 'PRP$'),
#     ('sales', 'NNS'),
#     ('.', '.'),
#     ('This', 'DT'),
#     ('involves', 'VBZ'),
#     ('supporting', 'VBG')]}},
#  {'status': 'UNLABELLED',
#   'data': {'raw': [('https', 'NN'),
#     (':', ':'),
#     ('//www.indeed.com/r/Akhil-Yadav-Polemaina/f6931801c51c63b1', 'JJ'),
#     ('?', '.'),
#     ('isid=rex-download', 'JJ'),
#     ('&', 'CC'),
#     ('ikw=download-top', 'JJ'),
#     ('&', 'CC'),
#     ('co=IN', 'NN')]}},
#  {'status': 'UNLABELLED',
#   'data': {'raw': [('https', 'NN'),
#     (':', ':'),
#     ('//www.indeed.com/r/Akhil-Yadav-Polemaina/f6931801c51c63b1', 'JJ'),
#     ('?', '.'),
#     ('isid=rex-download', 'JJ'),
#     ('&', 'CC'),
#     ('ikw=download-top', 'JJ'),
#     ('&', 'CC'),
#     ('co=IN', 'NN')]}},
#  {'status': 'UNLABELLED',
#   'data': {'raw': [('various', 'JJ'),
#     ('Decision', 'NNP'),
#     ('Support', 'NNP'),
#     ('System', 'NNP'),
#     ('reports', 'NNS'),
#     ('which', 'WDT'),
#     ('helps', 'VBZ'),
#     ('the', 'DT'),
#     ('higher', 'JJR'),
#     ('management', 'NN'),
#     ('to', 'TO'),
#     ('take', 'VB'),
#     ('business', 'NN')]}},
#  {'status': 'UNLABELLED',
#   'data': {'raw': [('critical', 'JJ'), ('decisions', 'NNS'), ('.', '.')]}},
#  {'status': 'UNLABELLED',
#   'data': {'raw': [('Responsibilities', 'NNS'), (':', ':')]}},
#  {'status': 'UNLABELLED',
#   'data': {'raw': [('●', 'JJ'),
#     ('Working', 'VBG'),
#     ('on', 'IN'),
#     ('all', 'PDT'),
#     ('the', 'DT'),
#     ('Major', 'NNP'),
#     ('and', 'CC'),
#     ('Minor', 'NNP'),
#     ('Enhancement', 'NNP'),
#     ('requests', 'NNS'),
#     ('as', 'IN'),
#     ('part', 'NN'),
#     ('of', 'IN'),
#     ('Maintenance', 'NNP'),
#     ('and', 'CC'),
#     ('Support', 'NNP')]}},
#  {'status': 'UNLABELLED', 'data': {'raw': [('activities', 'NNS')]}},
#  {'status': 'UNLABELLED',
#   'data': {'raw': [('●', 'NN'),
#     ('Identifying', 'NNP'),
#     ('and', 'CC'),
#     ('fixing', 'VBG'),
#     ('all', 'PDT'),
#     ('the', 'DT'),
#     ('major', 'JJ'),
#     ('defects', 'NNS'),
#     ('in', 'IN'),
#     ('the', 'DT'),
#     ('applications', 'NNS'),
#     (',', ','),
#     ('perform', 'VB'),
#     ('root', 'NN'),
#     ('cause', 'NN'),
#     ('analysis', 'NN'),
#     ('for', 'IN')]}},
#  {'status': 'UNLABELLED',
#   'data': {'raw': [('production', 'NN'), ('issues', 'NNS')]}},
#  {'status': 'UNLABELLED',
#   'data': {'raw': [('●', 'NN'),
#     ('Being', 'VBG'),
#     ('a', 'DT'),
#     ('subject', 'NN'),
#     ('matter', 'NN'),
#     ('expert', 'NN'),
#     (',', ','),
#     ('involved', 'VBN'),
#     ('in', 'IN'),
#     ('multiple', 'JJ'),
#     ('Knowledge', 'NNP'),
#     ('transfer', 'NN'),
#     ('and', 'CC'),
#     ('knowledge', 'NN'),
#     ('sharing', 'NN')]}},
#  {'status': 'UNLABELLED',
#   'data': {'raw': [('sessions', 'NNS'),
#     ('with', 'IN'),
#     ('the', 'DT'),
#     ('client', 'NN')]}},
#  {'status': 'UNLABELLED',
#   'data': {'raw': [('●', 'NN'),
#     ('Leading', 'VBG'),
#     ('a', 'DT'),
#     ('peer', 'NN'),
#     ('group', 'NN'),
#     ('and', 'CC'),
#     ('taking', 'VBG'),
#     ('end', 'NN'),
#     ('to', 'TO'),
#     ('end', 'VB'),
#     ('responsibilities', 'NNS'),
#     ('for', 'IN'),
#     ('all', 'PDT'),
#     ('the', 'DT'),
#     ('critical', 'JJ'),
#     ('issues/', 'NN')]}},
#  {'status': 'UNLABELLED',
#   'data': {'raw': [('enhancements', 'NNS'), ('.', '.')]}},
#  {'status': 'UNLABELLED',
#   'data': {'raw': [('●', 'NN'),
#     ('Identifying', 'VBG'),
#     ('the', 'DT'),
#     ('use', 'NN'),
#     ('cases', 'NNS'),
#     ('which', 'WDT'),
#     ('can', 'MD'),
#     ('be', 'VB'),
#     ('automated', 'VBN'),
#     ('using', 'VBG'),
#     ('Service', 'NNP'),
#     ('Now', 'RB'),
#     ('Orchestration', 'NNP')]}},
#  {'status': 'UNLABELLED',
#   'data': {'raw': [('●', 'NN'),
#     ('Creating', 'VBG'),
#     ('workflows', 'NNS'),
#     ('to', 'TO'),
#     ('automate', 'VB'),
#     ('various', 'JJ'),
#     ('tasks', 'NNS'),
#     ('which', 'WDT'),
#     ('involved', 'VBD'),
#     ('manual', 'JJ'),
#     ('intervention', 'NN')]}},
#  {'status': 'UNLABELLED',
#   'data': {'raw': [('●', 'NNS'),
#     ('Direct', 'JJ'),
#     ('interaction', 'NN'),
#     ('with', 'IN'),
#     ('the', 'DT'),
#     ('client', 'NN'),
#     ('on', 'IN'),
#     ('various', 'JJ'),
#     ('business', 'NN'),
#     ('impacting', 'VBG'),
#     ('issues', 'NNS'),
#     ('on', 'IN'),
#     ('a', 'DT'),
#     ('daily', 'JJ'),
#     ('basis', 'NN')]}},
#  {'status': 'UNLABELLED',
#   'data': {'raw': [('●', 'NN'),
#     ('Setting', 'VBG'),
#     ('up', 'RP'),
#     ('Weekly', 'JJ'),
#     ('Status', 'NNP'),
#     ('Review', 'NNP'),
#     ('meetings', 'NNS'),
#     ('and', 'CC'),
#     ('Code', 'NNP'),
#     ('Review', 'NNP'),
#     ('meetings', 'NNS'),
#     ('with', 'IN'),
#     ('the', 'DT'),
#     ('client', 'NN')]}},
#  {'status': 'UNLABELLED', 'data': {'raw': [('EDUCATION', 'NN')]}},
#  {'status': 'UNLABELLED',
#   'data': {'raw': [('Electrical', 'JJ'),
#     ('and', 'CC'),
#     ('Electronics', 'NNS'),
#     ('Engineering', 'VBG')]}},
#  {'status': 'UNLABELLED',
#   'data': {'raw': [('Anurag', 'NNP'),
#     ('College', 'NNP'),
#     ('of', 'IN'),
#     ('Engineering', 'NNP'),
#     ('(', '('),
#     ('Jntuh', 'NNP'),
#     (')', ')')]}},
#  {'status': 'UNLABELLED', 'data': {'raw': [('SKILLS', 'NN')]}},
#  {'status': 'UNLABELLED',
#   'data': {'raw': [('servicenow', 'NN'),
#     ('(', '('),
#     ('1', 'CD'),
#     ('year', 'NN'),
#     (')', ')'),
#     (',', ','),
#     ('Mainframe', 'NNP'),
#     ('(', '('),
#     ('3', 'CD'),
#     ('years', 'NNS'),
#     (')', ')'),
#     (',', ','),
#     ('cobol', 'NN'),
#     ('(', '('),
#     ('3', 'CD'),
#     ('years', 'NNS'),
#     (')', ')'),
#     (',', ','),
#     ('Jcl', 'NNP'),
#     ('(', '('),
#     ('3', 'CD'),
#     ('years', 'NNS'),
#     (')', ')'),
#     (',', ','),
#     ('Teradata', 'NNP'),
#     ('(', '('),
#     ('3', 'CD'),
#     ('years', 'NNS'),
#     (')', ')')]}},
#  {'status': 'UNLABELLED',
#   'data': {'raw': [('ADDITIONAL', 'DT'), ('INFORMATION', 'NN')]}},
#  {'status': 'UNLABELLED',
#   'data': {'raw': [('Technical', 'JJ'), ('Skills', 'NNS')]}},
#  {'status': 'UNLABELLED',
#   'data': {'raw': [('•', 'NN'),
#     ('Domain', 'NNP'),
#     ('-', ':'),
#     ('Retail', 'JJ')]}},
#  {'status': 'UNLABELLED',
#   'data': {'raw': [('•', 'NN'),
#     ('Technology', 'NNP'),
#     ('-', ':'),
#     ('Mainframe', 'NN'),
#     ('(', '('),
#     ('COBOL', 'NNP'),
#     (',', ','),
#     ('JCL', 'NNP'),
#     (',', ','),
#     ('DB2', 'NNP'),
#     (',', ','),
#     ('Teradata', 'NNP'),
#     (')', ')'),
#     (',', ','),
#     ('Service', 'NNP'),
#     ('now', 'RB'),
#     ('.', '.')]}},
#  {'status': 'UNLABELLED',
#   'data': {'raw': [('•', 'NN'),
#     ('Operating', 'VBG'),
#     ('System', 'NNP'),
#     ('-', ':'),
#     ('Mainframe', 'NN'),
#     ('(', '('),
#     ('z/OS', 'NN'),
#     (')', ')')]}},
#  {'status': 'UNLABELLED',
#   'data': {'raw': [('•', 'JJ'),
#     ('Database', 'NNP'),
#     ('-', ':'),
#     ('DB2', 'NNP'),
#     (',', ','),
#     ('SQL', 'NNP'),
#     (',', ','),
#     ('Teradata', 'NNP'),
#     ('.', '.')]}},
#  {'status': 'UNLABELLED',
#   'data': {'raw': [('•', 'NN'),
#     ('Utilities', 'NNS'),
#     ('-', ':'),
#     ('FILE-AID', 'NN'),
#     (',', ','),
#     ('IDCAMS', 'NNP'),
#     (',', ','),
#     ('DFSORT', 'NNP'),
#     ('basics', 'NNS'),
#     (',', ','),
#     ('LIBRARIAN', 'NNP'),
#     (',', ','),
#     ('FTP/SFTP', 'NNP'),
#     (',', ','),
#     ('CA-7', 'NNP'),
#     ('basics', 'NNS'),
#     ('.', '.')]}},
#  {'status': 'UNLABELLED',
#   'data': {'raw': [('•', 'NN'),
#     ('Tools', 'NNP'),
#     ('-', ':'),
#     ('Query', 'NNP'),
#     ('Management', 'NNP'),
#     ('Tool', 'NNP'),
#     ('(', '('),
#     ('QMF', 'NNP'),
#     (')', ')'),
#     (',', ','),
#     ('SQL', 'NNP'),
#     ('Assistant', 'NNP'),
#     (',', ','),
#     ('Service', 'NNP'),
#     ('now', 'RB'),
#     (',', ','),
#     ('Remedy', 'NNP'),
#     ('.', '.')]}},
#  {'status': 'UNLABELLED',
#   'data': {'raw': [('Key', 'JJ'), ('Strengths', 'NNS'), (':', ':')]}},
#  {'status': 'UNLABELLED',
#   'data': {'raw': [('●', 'JJ'),
#     ('Effective', 'NNP'),
#     ('Communication', 'NNP'),
#     ('Skills', 'NNP'),
#     ('and', 'CC'),
#     ('Zeal', 'NNP'),
#     ('to', 'TO'),
#     ('learn', 'VB'),
#     ('.', '.')]}},
#  {'status': 'UNLABELLED',
#   'data': {'raw': [('●', 'JJ'),
#     ('Flexibility', 'NNP'),
#     ('and', 'CC'),
#     ('Adaptability', 'NNP'),
#     ('.', '.')]}},
#  {'status': 'UNLABELLED',
#   'data': {'raw': [('●', 'RB'),
#     ('Good', 'JJ'),
#     ('Leadership', 'NNP'),
#     ('Qualities', 'NNP'),
#     ('.', '.')]}},
#  {'status': 'UNLABELLED',
#   'data': {'raw': [('●', 'JJ'),
#     ('Analytical', 'NNP'),
#     ('and', 'CC'),
#     ('Problem', 'NNP'),
#     ('Solving', 'NNP'),
#     ('Skills', 'NNP'),
#     ('.', '.')]}},
#  {'status': 'UNLABELLED',
#   'data': {'raw': [('Achievements', 'NNS'), (':', ':')]}},
#  {'status': 'UNLABELLED',
#   'data': {'raw': [('●', 'RB'),
#     ('Received', 'NNP'),
#     ('STAR', 'NNP'),
#     ('award', 'NN'),
#     ('for', 'IN'),
#     ('working', 'VBG'),
#     ('on', 'IN'),
#     ('various', 'JJ'),
#     ('system', 'NN'),
#     ('improvement', 'NN'),
#     ('and', 'CC'),
#     ('automation', 'NN'),
#     ('activities', 'NNS')]}},
#  {'status': 'UNLABELLED',
#   'data': {'raw': [('●', 'NNS'),
#     ('Received', 'VBD'),
#     ('multiple', 'JJ'),
#     ('INSTA', 'NNP'),
#     ('awards', 'NNS'),
#     ('for', 'IN'),
#     ('my', 'PRP$'),
#     ('performance', 'NN'),
#     ('in', 'IN'),
#     ('the', 'DT'),
#     ('projects', 'NNS'),
#     ('worked', 'VBD')]}},
#  {'status': 'UNLABELLED',
#   'data': {'raw': [('Alok', 'NNP'), ('Khandai', 'NNP')]}},
#  {'status': 'UNLABELLED',
#   'data': {'raw': [('Operational', 'JJ'),
#     ('Analyst', 'NNP'),
#     ('(', '('),
#     ('SQL', 'NNP'),
#     ('DBA', 'NNP'),
#     (')', ')'),
#     ('Engineer', 'NNP'),
#     ('-', ':'),
#     ('UNISYS', 'NN')]}},
#  {'status': 'UNLABELLED',
#   'data': {'raw': [('Bengaluru', 'NNP'),
#     (',', ','),
#     ('Karnataka', 'NNP'),
#     ('-', ':'),
#     ('Email', 'NNP'),
#     ('me', 'PRP'),
#     ('on', 'IN'),
#     ('Indeed', 'RB'),
#     (':', ':'),
#     ('indeed.com/r/Alok-Khandai/5be849e443b8f467', 'NN')]}},
#  {'status': 'UNLABELLED',
#   'data': {'raw': [('❖', 'NN'),
#     ('Having', 'VBG'),
#     ('3.5', 'CD'),
#     ('Years', 'NNS'),
#     ('of', 'IN'),
#     ('IT', 'NNP'),
#     ('experience', 'NN'),
#     ('in', 'IN'),
#     ('SQL', 'NNP'),
#     ('Database', 'NNP'),
#     ('Administration', 'NNP'),
#     (',', ','),
#     ('System', 'NNP'),
#     ('Analysis', 'NNP'),
#     (',', ','),
#     ('Design', 'NNP'),
#     (',', ',')]}},
#  {'status': 'UNLABELLED',
#   'data': {'raw': [('Development', 'NNP'),
#     ('&', 'CC'),
#     ('Support', 'NNP'),
#     ('of', 'IN'),
#     ('MS', 'NNP'),
#     ('SQL', 'NNP'),
#     ('Servers', 'NNP'),
#     ('in', 'IN'),
#     ('Production', 'NNP'),
#     (',', ','),
#     ('Development', 'NNP'),
#     ('environments', 'VBZ'),
#     ('&', 'CC')]}},
#  {'status': 'UNLABELLED',
#   'data': {'raw': [('Replication', 'NN'),
#     ('and', 'CC'),
#     ('Cluster', 'NNP'),
#     ('Server', 'NNP'),
#     ('Environments', 'NNP'),
#     ('.', '.')]}},
#  {'status': 'UNLABELLED',
#   'data': {'raw': [('❖', 'JJ'),
#     ('Working', 'NNP'),
#     ('Experience', 'NN'),
#     ('with', 'IN'),
#     ('relational', 'JJ'),
#     ('database', 'NN'),
#     ('such', 'JJ'),
#     ('as', 'IN'),
#     ('SQL', 'NNP'),
#     ('.', '.')]}},
#  {'status': 'UNLABELLED',
#   'data': {'raw': [('❖', 'JJ'),
#     ('Experience', 'NNP'),
#     ('in', 'IN'),
#     ('Installation', 'NNP'),
#     (',', ','),
#     ('Configuration', 'NNP'),
#     (',', ','),
#     ('Maintenance', 'NNP'),
#     ('and', 'CC'),
#     ('Administration', 'NNP'),
#     ('of', 'IN'),
#     ('SQL', 'NNP'),
#     ('Server', 'NNP'),
#     ('.', '.')]}},
#  {'status': 'UNLABELLED',
#   'data': {'raw': [('❖', 'JJ'),
#     ('Experience', 'NNP'),
#     ('in', 'IN'),
#     ('upgrading', 'VBG'),
#     ('SQL', 'NNP'),
#     ('Server', 'NNP'),
#     ('.', '.')]}},
#  {'status': 'UNLABELLED',
#   'data': {'raw': [('❖', 'RB'),
#     ('Good', 'JJ'),
#     ('experience', 'NN'),
#     ('with', 'IN'),
#     ('implementing', 'VBG'),
#     ('DR', 'NNP'),
#     ('solution', 'NN'),
#     (',', ','),
#     ('High', 'NNP'),
#     ('Availability', 'NNP'),
#     ('of', 'IN'),
#     ('database', 'NN'),
#     ('servers', 'NNS'),
#     ('using', 'VBG')]}},
#  {'status': 'UNLABELLED',
#   'data': {'raw': [('Database', 'NNP'),
#     ('mirroring', 'NN'),
#     ('and', 'CC'),
#     ('replications', 'NNS'),
#     ('and', 'CC'),
#     ('Log', 'NNP'),
#     ('Shipping', 'NNP'),
#     ('.', '.')]}},
#  {'status': 'UNLABELLED',
#   'data': {'raw': [('❖', 'JJ'),
#     ('Experience', 'NNP'),
#     ('in', 'IN'),
#     ('implementing', 'VBG'),
#     ('SQL', 'NNP'),
#     ('Server', 'NNP'),
#     ('security', 'NN'),
#     ('and', 'CC'),
#     ('Object', 'NNP'),
#     ('permissions', 'NNS'),
#     ('like', 'IN'),
#     ('maintaining', 'VBG')]}},
#  {'status': 'UNLABELLED',
#   'data': {'raw': [('Database', 'NNP'),
#     ('authentication', 'NN'),
#     ('modes', 'NNS'),
#     (',', ','),
#     ('creation', 'NN'),
#     ('of', 'IN'),
#     ('users', 'NNS'),
#     (',', ','),
#     ('configuring', 'VBG'),
#     ('permissions', 'NNS'),
#     ('and', 'CC'),
#     ('assigning', 'VBG'),
#     ('roles', 'NNS')]}},
#  {'status': 'UNLABELLED',
#   'data': {'raw': [('to', 'TO'), ('users', 'NNS'), ('.', '.')]}},
#  {'status': 'UNLABELLED',
#   'data': {'raw': [('❖', 'JJ'),
#     ('Experience', 'NNP'),
#     ('in', 'IN'),
#     ('creating', 'VBG'),
#     ('Jobs', 'NNP'),
#     (',', ','),
#     ('Alerts', 'NNP'),
#     (',', ','),
#     ('SQL', 'NNP'),
#     ('Mail', 'NNP'),
#     ('Agent', 'NNP')]}},
#  {'status': 'UNLABELLED',
#   'data': {'raw': [('❖', 'JJ'),
#     ('Experience', 'NNP'),
#     ('in', 'IN'),
#     ('performing', 'VBG'),
#     ('integrity', 'NN'),
#     ('checks', 'NNS'),
#     ('.', '.'),
#     ('Methods', 'NNS'),
#     ('include', 'VBP'),
#     ('configuring', 'VBG'),
#     ('the', 'DT'),
#     ('database', 'NN')]}},
#  {'status': 'UNLABELLED',
#   'data': {'raw': [('maintenance', 'NN'),
#     ('plan', 'NN'),
#     ('wizard', 'NN'),
#     ('and', 'CC'),
#     ('DBCC', 'NNP'),
#     ('utilities', 'NNS')]}},
#  {'status': 'UNLABELLED',
#   'data': {'raw': [('❖', 'JJ'),
#     ('Experience', 'NN'),
#     ('in', 'IN'),
#     ('using', 'VBG'),
#     ('Performance', 'NNP'),
#     ('Monitor', 'NNP'),
#     (',', ','),
#     ('SQL', 'NNP'),
#     ('Profiler', 'NNP'),
#     ('and', 'CC'),
#     ('optimizing', 'VBG'),
#     ('the', 'DT'),
#     ('queries', 'NNS'),
#     (',', ','),
#     ('tracing', 'VBG'),
#     ('long', 'RB')]}},
#  {'status': 'UNLABELLED',
#   'data': {'raw': [('running', 'VBG'),
#     ('queries', 'NNS'),
#     ('and', 'CC'),
#     ('deadlocks', 'NNS'),
#     ('.', '.')]}},
#  {'status': 'UNLABELLED',
#   'data': {'raw': [('❖', 'JJ'),
#     ('Experience', 'NNP'),
#     ('in', 'IN'),
#     ('applying', 'VBG'),
#     ('patches', 'NNS'),
#     ('and', 'CC'),
#     ('service', 'NN'),
#     ('packs', 'NNS'),
#     ('to', 'TO'),
#     ('keep', 'VB'),
#     ('the', 'DT'),
#     ('database', 'NN'),
#     ('at', 'IN'),
#     ('current', 'JJ'),
#     ('patch', 'NN'),
#     ('level', 'NN'),
#     ('.', '.')]}},
#  {'status': 'UNLABELLED',
#   'data': {'raw': [('❖', 'JJ'),
#     ('Ability', 'NNP'),
#     ('to', 'TO'),
#     ('manage', 'VB'),
#     ('own', 'JJ'),
#     ('work', 'NN'),
#     ('and', 'CC'),
#     ('multitask', 'NN'),
#     ('to', 'TO'),
#     ('meet', 'VB'),
#     ('tight', 'JJ'),
#     ('deadlines', 'NNS'),
#     ('without', 'IN'),
#     ('losing', 'VBG'),
#     ('sight', 'NN'),
#     ('of', 'IN')]}},
#  {'status': 'UNLABELLED',
#   'data': {'raw': [('priorities', 'NNS'), ('..', 'VBP')]}},
#  {'status': 'UNLABELLED',
#   'data': {'raw': [('Willing', 'VBG'),
#     ('to', 'TO'),
#     ('relocate', 'VB'),
#     ('to', 'TO'),
#     (':', ':'),
#     ('Bengaluru', 'NNP'),
#     (',', ','),
#     ('Karnataka', 'NNP')]}},
#  {'status': 'UNLABELLED',
#   'data': {'raw': [('WORK', 'NN'), ('EXPERIENCE', 'NN')]}},
#  {'status': 'UNLABELLED',
#   'data': {'raw': [('Operational', 'JJ'),
#     ('Analyst', 'NNP'),
#     ('(', '('),
#     ('SQL', 'NNP'),
#     ('DBA', 'NNP'),
#     (')', ')'),
#     ('Engineer', 'NN')]}},
#  {'status': 'UNLABELLED',
#   'data': {'raw': [('UNISYS', 'NNP'),
#     ('-', ':'),
#     ('Bengaluru', 'NNP'),
#     (',', ','),
#     ('Karnataka', 'NNP'),
#     ('-', ':')]}},
#  {'status': 'UNLABELLED',
#   'data': {'raw': [('July', 'NNP'),
#     ('2016', 'CD'),
#     ('to', 'TO'),
#     ('Present', 'VB')]}},
#  {'status': 'UNLABELLED',
#   'data': {'raw': [('❖', 'NN'),
#     ('Having', 'VBG'),
#     ('3.5', 'CD'),
#     ('Years', 'NNS'),
#     ('of', 'IN'),
#     ('IT', 'NNP'),
#     ('experience', 'NN'),
#     ('in', 'IN'),
#     ('SQL', 'NNP'),
#     ('Database', 'NNP'),
#     ('Administration', 'NNP'),
#     (',', ','),
#     ('System', 'NNP'),
#     ('Analysis', 'NNP'),
#     (',', ','),
#     ('Design', 'NNP'),
#     (',', ',')]}},
#  {'status': 'UNLABELLED',
#   'data': {'raw': [('Development', 'NNP'),
#     ('&', 'CC'),
#     ('Support', 'NNP'),
#     ('of', 'IN'),
#     ('MS', 'NNP'),
#     ('SQL', 'NNP'),
#     ('Servers', 'NNP'),
#     ('in', 'IN'),
#     ('Production', 'NNP'),
#     (',', ','),
#     ('Development', 'NNP'),
#     ('environments', 'VBZ'),
#     ('&', 'CC')]}},
#  {'status': 'UNLABELLED',
#   'data': {'raw': [('Replication', 'NN'),
#     ('and', 'CC'),
#     ('Cluster', 'NNP'),
#     ('Server', 'NNP'),
#     ('Environments', 'NNP'),
#     ('.', '.')]}},
#  {'status': 'UNLABELLED',
#   'data': {'raw': [('❖', 'JJ'),
#     ('Working', 'NNP'),
#     ('Experience', 'NN'),
#     ('with', 'IN'),
#     ('relational', 'JJ'),
#     ('database', 'NN'),
#     ('such', 'JJ'),
#     ('as', 'IN'),
#     ('SQL', 'NNP'),
#     ('.', '.')]}},
#  {'status': 'UNLABELLED',
#   'data': {'raw': [('❖', 'JJ'),
#     ('Experience', 'NNP'),
#     ('in', 'IN'),
#     ('Installation', 'NNP'),
#     (',', ','),
#     ('Configuration', 'NNP'),
#     (',', ','),
#     ('Maintenance', 'NNP'),
#     ('and', 'CC'),
#     ('Administration', 'NNP'),
#     ('of', 'IN'),
#     ('SQL', 'NNP'),
#     ('Server', 'NNP'),
#     ('.', '.')]}},
#  {'status': 'UNLABELLED',
#   'data': {'raw': [('❖', 'JJ'),
#     ('Experience', 'NNP'),
#     ('in', 'IN'),
#     ('upgrading', 'VBG'),
#     ('SQL', 'NNP'),
#     ('Server', 'NNP'),
#     ('.', '.')]}},
#  {'status': 'UNLABELLED',
#   'data': {'raw': [('❖', 'RB'),
#     ('Good', 'JJ'),
#     ('experience', 'NN'),
#     ('with', 'IN'),
#     ('implementing', 'VBG'),
#     ('DR', 'NNP'),
#     ('solution', 'NN'),
#     (',', ','),
#     ('High', 'NNP'),
#     ('Availability', 'NNP'),
#     ('of', 'IN'),
#     ('database', 'NN'),
#     ('servers', 'NNS'),
#     ('using', 'VBG')]}},
#  {'status': 'UNLABELLED',
#   'data': {'raw': [('Database', 'NNP'),
#     ('mirroring', 'NN'),
#     ('and', 'CC'),
#     ('replications', 'NNS'),
#     ('and', 'CC'),
#     ('Log', 'NNP'),
#     ('Shipping', 'NNP'),
#     ('.', '.')]}},
#  {'status': 'UNLABELLED',
#   'data': {'raw': [('❖', 'JJ'),
#     ('Experience', 'NNP'),
#     ('in', 'IN'),
#     ('implementing', 'VBG'),
#     ('SQL', 'NNP'),
#     ('Server', 'NNP'),
#     ('security', 'NN'),
#     ('and', 'CC'),
#     ('Object', 'NNP'),
#     ('permissions', 'NNS'),
#     ('like', 'IN'),
#     ('maintaining', 'VBG')]}},
#  {'status': 'UNLABELLED',
#   'data': {'raw': [('Database', 'NNP'),
#     ('authentication', 'NN'),
#     ('modes', 'NNS'),
#     (',', ','),
#     ('creation', 'NN'),
#     ('of', 'IN'),
#     ('users', 'NNS'),
#     (',', ','),
#     ('configuring', 'VBG'),
#     ('permissions', 'NNS'),
#     ('and', 'CC'),
#     ('assigning', 'VBG'),
#     ('roles', 'NNS')]}},
#  {'status': 'UNLABELLED',
#   'data': {'raw': [('to', 'TO'), ('users', 'NNS'), ('.', '.')]}},
#  {'status': 'UNLABELLED',
#   'data': {'raw': [('DBA', 'NNP'), ('Support', 'NNP'), ('Analyst', 'NNP')]}},
#  {'status': 'UNLABELLED',
#   'data': {'raw': [('Microsoft', 'NNP'),
#     ('Corporation', 'NNP'),
#     ('-', ':'),
#     ('Redmond', 'NN'),
#     (',', ','),
#     ('WA', 'NNP'),
#     ('-', ':')]}},
#  {'status': 'UNLABELLED',
#   'data': {'raw': [('https', 'NN'),
#     (':', ':'),
#     ('//www.indeed.com/r/Alok-Khandai/5be849e443b8f467', 'JJ'),
#     ('?', '.'),
#     ('isid=rex-download', 'JJ'),
#     ('&', 'CC'),
#     ('ikw=download-top', 'JJ'),
#     ('&', 'CC'),
#     ('co=IN', 'NN')]}},
#  {'status': 'UNLABELLED',
#   'data': {'raw': [('July', 'NNP'),
#     ('2016', 'CD'),
#     ('to', 'TO'),
#     ('Present', 'VB')]}},
#  {'status': 'UNLABELLED',
#   'data': {'raw': [('Client', 'JJ'), ('Description', 'NN'), (':', ':')]}},
#  {'status': 'UNLABELLED',
#   'data': {'raw': [('Microsoft', 'NNP'),
#     ('Corporation', 'NNP'),
#     ('is', 'VBZ'),
#     ('an', 'DT'),
#     ('American', 'JJ'),
#     ('public', 'JJ'),
#     ('multinational', 'JJ'),
#     ('corporation', 'NN'),
#     ('headquartered', 'VBD'),
#     ('in', 'IN')]}},
#  {'status': 'UNLABELLED',
#   'data': {'raw': [('Redmond', 'NN'),
#     (',', ','),
#     ('Washington', 'NNP'),
#     (',', ','),
#     ('USA', 'NNP'),
#     ('that', 'IN'),
#     ('develops', 'VBZ'),
#     (',', ','),
#     ('manufactures', 'NNS'),
#     (',', ','),
#     ('licenses', 'NNS'),
#     (',', ','),
#     ('and', 'CC'),
#     ('supports', 'VBZ'),
#     ('a', 'DT'),
#     ('wide', 'JJ'),
#     ('range', 'NN'),
#     ('of', 'IN')]}},
#  {'status': 'UNLABELLED',
#   'data': {'raw': [('products', 'NNS'),
#     ('and', 'CC'),
#     ('services', 'NNS'),
#     ('predominantly', 'RB'),
#     ('related', 'VBN'),
#     ('to', 'TO'),
#     ('computing', 'VBG'),
#     ('through', 'IN'),
#     ('its', 'PRP$'),
#     ('various', 'JJ'),
#     ('product', 'NN'),
#     ('divisions', 'NNS'),
#     ('.', '.')]}},
#  {'status': 'UNLABELLED',
#   'data': {'raw': [('Environment', 'NN'), (':', ':')]}},
#  {'status': 'UNLABELLED',
#   'data': {'raw': [('Microsoft', 'NNP'),
#     ('has', 'VBZ'),
#     ('E2E', 'NNP'),
#     ('development', 'NN'),
#     ('and', 'CC'),
#     ('production', 'NN'),
#     ('environment', 'NN'),
#     ('of', 'IN'),
#     ('more', 'JJR'),
#     ('than', 'IN'),
#     ('25000', 'CD'),
#     ('servers', 'NNS'),
#     ('and', 'CC')]}},
#  {'status': 'UNLABELLED',
#   'data': {'raw': [('applications', 'NNS'),
#     ('.', '.'),
#     ('We', 'PRP'),
#     ('are', 'VBP'),
#     ('responsible', 'JJ'),
#     ('for', 'IN'),
#     ('pro-active', 'JJ'),
#     ('monitoring', 'NN'),
#     ('of', 'IN'),
#     ('all', 'PDT'),
#     ('the', 'DT'),
#     ('servers', 'NNS'),
#     ('and', 'CC'),
#     ('their', 'PRP$'),
#     ('jobs', 'NNS'),
#     ('using', 'VBG')]}},
#  {'status': 'UNLABELLED',
#   'data': {'raw': [('monitoring', 'NN'),
#     ('tools', 'NNS'),
#     ('to', 'TO'),
#     ('reduce', 'VB'),
#     ('critical', 'JJ'),
#     ('business', 'NN'),
#     ('impact', 'NN'),
#     ('by', 'IN'),
#     ('alerting', 'VBG'),
#     ('respective', 'JJ'),
#     ('peer', 'NN'),
#     ('teams', 'NNS'),
#     ('.', '.'),
#     ('Microsoft', 'NNP')]}},
#  {'status': 'UNLABELLED',
#   'data': {'raw': [('Service', 'NNP'),
#     ('Enterprise', 'NNP'),
#     ('an', 'DT'),
#     ('ITSM', 'NNP'),
#     ('tools', 'NNS'),
#     ('are', 'VBP'),
#     ('used', 'VBN'),
#     ('for', 'IN'),
#     ('ticketing', 'VBG'),
#     ('and', 'CC'),
#     ('SharePoint', 'NNP'),
#     ('portal', 'NN'),
#     ('is', 'VBZ'),
#     ('used', 'VBN'),
#     ('to', 'TO'),
#     ('store', 'VB'),
#     ('all', 'DT')]}},
#  {'status': 'UNLABELLED',
#   'data': {'raw': [('technical', 'JJ'),
#     ('and', 'CC'),
#     ('process', 'JJ'),
#     ('documentation', 'NN'),
#     ('.', '.')]}},
#  {'status': 'UNLABELLED',
#   'data': {'raw': [('Roles', 'NNS'),
#     ('and', 'CC'),
#     ('Responsibilities', 'NNS'),
#     (':', ':')]}},
#  {'status': 'UNLABELLED',
#   'data': {'raw': [('•', 'NN'),
#     ('Responsible', 'NNP'),
#     ('for', 'IN'),
#     ('Database', 'NNP'),
#     ('support', 'NN'),
#     (',', ','),
#     ('troubleshooting', 'VBG'),
#     (',', ','),
#     ('planning', 'NN'),
#     ('and', 'CC'),
#     ('migration', 'NN'),
#     ('.', '.'),
#     ('Resource', 'NNP'),
#     ('planning', 'NN')]}},
#  {'status': 'UNLABELLED',
#   'data': {'raw': [('and', 'CC'),
#     ('coordination', 'NN'),
#     ('for', 'IN'),
#     ('application', 'NN'),
#     ('migrations', 'NNS'),
#     ('with', 'IN'),
#     ('project', 'NN'),
#     ('managers', 'NNS'),
#     (',', ','),
#     ('application', 'NN'),
#     ('and', 'CC'),
#     ('web', 'NN'),
#     ('app', 'NN')]}},
#  {'status': 'UNLABELLED',
#   'data': {'raw': [('teams', 'NNS'),
#     ('.', '.'),
#     ('Project', 'NN'),
#     ('involved', 'VBN'),
#     ('guidance', 'NN'),
#     ('and', 'CC'),
#     ('adherence', 'NN'),
#     ('to', 'TO'),
#     ('standardized', 'VB'),
#     ('procedures', 'NNS'),
#     ('for', 'IN'),
#     ('planned', 'VBN'),
#     ('data', 'NNS')]}},
#  {'status': 'UNLABELLED',
#   'data': {'raw': [('center', 'NN'),
#     ('consolidation', 'NN'),
#     ('for', 'IN'),
#     ('worldwide', 'NN'),
#     ('centers', 'NNS'),
#     ('using', 'VBG'),
#     ('in-house', 'JJ'),
#     ('corporate', 'JJ'),
#     ('and', 'CC'),
#     ('third', 'JJ'),
#     ('party', 'NN'),
#     ('applications', 'NNS')]}},
#  {'status': 'UNLABELLED',
#   'data': {'raw': [('based', 'VBN'),
#     ('on', 'IN'),
#     ('SQL', 'NNP'),
#     ('2000', 'CD'),
#     ('in', 'IN'),
#     ('upgrade', 'JJ'),
#     ('project', 'NN'),
#     ('to', 'TO'),
#     ('SQL', 'VB'),
#     ('2005', 'CD'),
#     ('.', '.')]}},
#  {'status': 'UNLABELLED',
#   'data': {'raw': [('•', 'JJ'),
#     ('Monitoring', 'NNP'),
#     ('of', 'IN'),
#     ('database', 'NN'),
#     ('size', 'NN'),
#     ('and', 'CC'),
#     ('disk', 'NN'),
#     ('space', 'NN'),
#     ('in', 'IN'),
#     ('Production', 'NNP'),
#     (',', ','),
#     ('Staging', 'NNP'),
#     ('&', 'CC'),
#     ('Development', 'NNP'),
#     ('environments', 'NNS')]}},
#  {'status': 'UNLABELLED',
#   'data': {'raw': [('•', 'NN'),
#     ('Performed', 'NNP'),
#     ('installation', 'NN'),
#     ('of', 'IN'),
#     ('SQL', 'NNP'),
#     ('Enterprise', 'NNP'),
#     ('2005', 'CD'),
#     ('64bit', 'CD'),
#     ('version', 'NN'),
#     ('on', 'IN'),
#     ('Windows', 'NNP'),
#     ('2003', 'CD'),
#     ('servers', 'NNS'),
#     ('on', 'IN')]}},
#  {'status': 'UNLABELLED',
#   'data': {'raw': [('Enterprise', 'NNP'),
#     ('systems', 'NNS'),
#     ('of', 'IN'),
#     ('clustered', 'JJ'),
#     ('and', 'CC'),
#     ('standalone', 'JJ'),
#     ('servers', 'NNS'),
#     ('in', 'IN'),
#     ('enterprise', 'NN'),
#     ('Data', 'NNP'),
#     ('Centers', 'NNP'),
#     ('.', '.'),
#     ('Patch', 'VB')]}},
#  {'status': 'UNLABELLED',
#   'data': {'raw': [('applications', 'NNS'), ('.', '.')]}},
#  {'status': 'UNLABELLED',
#   'data': {'raw': [('•', 'NN'),
#     ('Failover', 'NNP'),
#     ('cluster', 'NN'),
#     ('testing', 'VBG'),
#     ('and', 'CC'),
#     ('resolution', 'NN'),
#     ('on', 'IN'),
#     ('HP', 'NNP'),
#     ('servers', 'NNS'),
#     ('as', 'RB'),
#     ('well', 'RB'),
#     ('as', 'IN'),
#     ('monitoring', 'NN'),
#     ('and', 'CC'),
#     ('backup', 'NN'),
#     ('reporting', 'NN')]}},
# ...
#     ('…', 'NNP'),
#     (']', 'NNP'),
#     ('Windows95/98/XP/NT', 'NNP')]}},
#  {'status': 'UNLABELLED',
#   'data': {'raw': [('❖', 'JJ'),
#     ('Database', 'NNP'),
#     ('Tool', 'NNP'),
#     (':', ':'),
#     ('SQL', 'NNP'),
#     ('Management', 'NNP'),
#     ('Studio', 'NNP'),
#     ('(', '('),
#     ('MSSQL', 'NNP'),
#     (')', ')'),
#     (',', ','),
#     ('Business', 'NNP')]}},
#  {'status': 'UNLABELLED',
#   'data': {'raw': [('Development', 'NNP'),
#     ('Studio', 'NNP'),
#     (',', ','),
#     ('Visual', 'NNP'),
#     ('studio', 'NN'),
#     ('2005', 'CD')]}},
#  {'status': 'UNLABELLED',
#   'data': {'raw': [('❖', 'JJ'),
#     ('Database', 'NNP'),
#     ('Language', 'NN'),
#     (':', ':'),
#     ('SQL', 'NNP'),
#     (',', ','),
#     ('PL/SQL', 'NNP')]}},
#  {'status': 'UNLABELLED',
#   'data': {'raw': [('❖', 'NN'),
#     ('Ticket', 'NNP'),
#     ('Tracking', 'NNP'),
#     ('Tool', 'NNP'),
#     (':', ':'),
#     ('Service', 'NNP'),
#     ('Now', 'RB')]}},
#  {'status': 'UNLABELLED',
#   'data': {'raw': [('❖', 'JJ'),
#     ('Reporting', 'NNP'),
#     ('Tools', 'NNP'),
#     (':', ':'),
#     ('MS', 'NNP'),
#     ('Reporting', 'NNP'),
#     ('Services', 'NNPS'),
#     (',', ','),
#     ('SAS', 'NNP')]}},
#  {'status': 'UNLABELLED',
#   'data': {'raw': [('❖', 'JJ'),
#     ('Languages', 'NNS'),
#     (':', ':'),
#     ('C', 'NNP'),
#     (',', ','),
#     ('C++', 'NNP'),
#     (',', ','),
#     ('PL/SQL', 'NNP')]}},
#  {'status': 'UNLABELLED',
#   'data': {'raw': [('Ananya', 'NNP'), ('Chavan', 'NNP')]}},
#  {'status': 'UNLABELLED',
#   'data': {'raw': [('lecturer', 'SYM'),
#     ('-', ':'),
#     ('oracle', 'NN'),
#     ('tutorials', 'NNS')]}},
#  {'status': 'UNLABELLED',
#   'data': {'raw': [('Mumbai', 'NNP'),
#     (',', ','),
#     ('Maharashtra', 'NNP'),
#     ('-', ':'),
#     ('Email', 'NNP'),
#     ('me', 'PRP'),
#     ('on', 'IN'),
#     ('Indeed', 'RB'),
#     (':', ':'),
#     ('indeed.com/r/Ananya-', 'NN')]}},
#  {'status': 'UNLABELLED',
#   'data': {'raw': [('Chavan/738779ab71971a96', 'NN')]}},
#  {'status': 'UNLABELLED',
#   'data': {'raw': [('Seeking', 'VBG'),
#     ('a', 'DT'),
#     ('responsible', 'JJ'),
#     ('job', 'NN'),
#     ('with', 'IN'),
#     ('an', 'DT'),
#     ('opportunity', 'NN'),
#     ('for', 'IN'),
#     ('professional', 'JJ'),
#     ('challenges', 'NNS'),
#     ('and', 'CC'),
#     ('utilize', 'VB'),
#     ('my', 'PRP$'),
#     ('skills', 'NNS')]}},
#  {'status': 'UNLABELLED',
#   'data': {'raw': [('up', 'RB'),
#     ('to', 'TO'),
#     ('its', 'PRP$'),
#     ('extreme', 'NN'),
#     ('.', '.')]}},
#  {'status': 'UNLABELLED',
#   'data': {'raw': [('WORK', 'NN'), ('EXPERIENCE', 'NN')]}},
#  {'status': 'UNLABELLED', 'data': {'raw': [('lecturer', 'NN')]}},
#  {'status': 'UNLABELLED',
#   'data': {'raw': [('Oracle', 'NN'),
#     ('tutorials', 'NNS'),
#     ('-', ':'),
#     ('Mumbai', 'NNP'),
#     (',', ','),
#     ('Maharashtra', 'NNP'),
#     ('-', ':')]}},
#  {'status': 'UNLABELLED',
#   'data': {'raw': [('April', 'NNP'),
#     ('2016', 'CD'),
#     ('to', 'TO'),
#     ('Present', 'VB')]}},
#  {'status': 'UNLABELLED',
#   'data': {'raw': [('for', 'IN'),
#     ('computer', 'NN'),
#     ('science', 'NN'),
#     ('(', '('),
#     ('STD', 'NNP'),
#     ('11th', 'CD'),
#     ('and', 'CC'),
#     ('12th', 'CD'),
#     (')', ')'),
#     ('(', '('),
#     ('2', 'CD'),
#     ('years', 'NNS'),
#     (')', ')')]}},
#  {'status': 'UNLABELLED',
#   'data': {'raw': [('➢', 'NN'),
#     ('Worked', 'VBD'),
#     ('at', 'IN'),
#     ('``', '``'),
#     ('Dr.Babasaheb', 'NNP'),
#     ('Ambedkar', 'NNP'),
#     ('College', 'NNP'),
#     (',', ','),
#     ('Chembur', 'NNP'),
#     ('(', '('),
#     ('W', 'NNP'),
#     (')', ')'),
#     ('``', '``'),
#     ('as', 'IN'),
#     ('a', 'DT'),
#     ('lecturer', 'NN'),
#     ('for', 'IN'),
#     ('•', 'JJ'),
#     ('B.Sc', 'NNP'),
#     ('.', '.'),
#     ('(', '('),
#     ('Computer', 'NNP')]}},
#  {'status': 'UNLABELLED',
#   'data': {'raw': [('Science', 'NNP'),
#     ('&', 'CC'),
#     ('Information', 'NNP'),
#     ('Technology', 'NNP'),
#     (')', ')')]}},
#  {'status': 'UNLABELLED',
#   'data': {'raw': [('•', 'JJ'),
#     ('F.Y.J.C', 'NNP'),
#     ('.', '.'),
#     ('(', '('),
#     ('Computer', 'NNP'),
#     ('Science', 'NNP'),
#     ('&', 'CC'),
#     ('I.T', 'NNP'),
#     ('.', '.'),
#     (')', ')')]}},
#  {'status': 'UNLABELLED',
#   'data': {'raw': [('•', 'JJ'),
#     ('S.Y.J.C', 'NNP'),
#     ('.', '.'),
#     ('(', '('),
#     ('Computer', 'NNP'),
#     ('Science', 'NNP'),
#     ('&', 'CC'),
#     ('I.T', 'NNP'),
#     ('.', '.'),
#     (')', ')')]}},
#  {'status': 'UNLABELLED',
#   'data': {'raw': [('➢', 'NN'),
#     ('Worked', 'VBD'),
#     ('at', 'IN'),
#     ('``', '``'),
#     ('LIVE', 'NNP'),
#     ("''", "''"),
#     ('as', 'IN'),
#     ('a', 'DT'),
#     ('Head', 'NNP'),
#     ('of', 'IN'),
#     ('the', 'DT'),
#     ('IT', 'NNP'),
#     ('Department', 'NNP'),
#     ('and', 'CC'),
#     ('Lecturer', 'NNP'),
#     ('for', 'IN'),
#     ('Web', 'NNP'),
#     ('designing', 'NN'),
#     ('.', '.')]}},
#  {'status': 'UNLABELLED',
#   'data': {'raw': [('➢', 'NN'),
#     ('Worked', 'VBD'),
#     ('at', 'IN'),
#     ('``', '``'),
#     ('Kohinoor', 'NNP'),
#     ('College', 'NNP'),
#     ('Of', 'IN'),
#     ('Hotel', 'NNP'),
#     ('Management', 'NNP'),
#     ("''", "''"),
#     ('as', 'IN'),
#     ('visiting', 'JJ'),
#     ('lecturer', 'NN'),
#     ('for', 'IN'),
#     ('SEM', 'NNP'),
#     ('I', 'PRP'),
#     ('.', '.')]}},
#  {'status': 'UNLABELLED',
#   'data': {'raw': [('➢', 'NN'),
#     ('Working', 'VBG'),
#     ('at', 'IN'),
#     ('``', '``'),
#     ('ORACLE', 'NNP'),
#     ('TUTORIALS', 'NNP'),
#     ("''", "''"),
#     ('as', 'IN'),
#     ('a', 'DT'),
#     ('lecturer', 'NN'),
#     ('for', 'IN'),
#     ('computer', 'NN'),
#     ('science', 'NN'),
#     ('(', '('),
#     ('STD', 'NNP'),
#     ('11th', 'CD'),
#     ('and', 'CC'),
#     ('12th', 'CD'),
#     (')', ')')]}},
#  {'status': 'UNLABELLED', 'data': {'raw': [('EDUCATION', 'NN')]}},
#  {'status': 'UNLABELLED', 'data': {'raw': [('MCA', 'NNP')]}},
#  {'status': 'UNLABELLED',
#   'data': {'raw': [('Mumbai', 'NNP'),
#     ('University', 'NNP'),
#     ('-', ':'),
#     ('Mumbai', 'NNP'),
#     (',', ','),
#     ('Maharashtra', 'NNP')]}},
#  {'status': 'UNLABELLED',
#   'data': {'raw': [('B.Sc', 'NNP'),
#     ('.', '.'),
#     ('in', 'IN'),
#     ('Com.Sci', 'NNP')]}},
#  {'status': 'UNLABELLED',
#   'data': {'raw': [('Mumbai', 'NNP'),
#     ('University', 'NNP'),
#     ('-', ':'),
#     ('Mumbai', 'NNP'),
#     (',', ','),
#     ('Maharashtra', 'NNP')]}},
#  {'status': 'UNLABELLED', 'data': {'raw': [('SKILLS', 'NN')]}},
#  {'status': 'UNLABELLED',
#   'data': {'raw': [('SEARCH', 'NNP'),
#     ('ENGINE', 'NNP'),
#     ('MARKETING', 'NNP'),
#     ('(', '('),
#     ('2', 'CD'),
#     ('years', 'NNS'),
#     (')', ')'),
#     (',', ','),
#     ('SEM', 'NNP'),
#     ('(', '('),
#     ('2', 'CD'),
#     ('years', 'NNS'),
#     (')', ')'),
#     (',', ','),
#     ('ACCESS', 'NNP'),
#     ('(', '('),
#     ('Less', 'NNP'),
#     ('than', 'IN'),
#     ('1', 'CD'),
#     ('year', 'NN'),
#     (')', ')'),
#     (',', ','),
#     ('AJAX', 'NNP'),
#     ('(', '('),
#     ('Less', 'NNP')]}},
#  {'status': 'UNLABELLED',
#   'data': {'raw': [('than', 'IN'),
#     ('1', 'CD'),
#     ('year', 'NN'),
#     (')', ')'),
#     (',', ','),
#     ('APACHE', 'NNP'),
#     ('(', '('),
#     ('Less', 'NNP'),
#     ('than', 'IN'),
#     ('1', 'CD'),
#     ('year', 'NN'),
#     (')', ')')]}},
#  {'status': 'UNLABELLED',
#   'data': {'raw': [('ADDITIONAL', 'DT'), ('INFORMATION', 'NN')]}},
#  {'status': 'UNLABELLED',
#   'data': {'raw': [('Technical', 'JJ'), ('skills', 'NNS'), (':', ':')]}},
#  {'status': 'UNLABELLED',
#   'data': {'raw': [('Languages', 'NNS'),
#     (':', ':'),
#     ('C', 'NNP'),
#     (',', ','),
#     ('C++', 'NNP'),
#     (',', ','),
#     ('Java', 'NNP'),
#     ('(', '('),
#     ('J2EE', 'NNP'),
#     (')', ')'),
#     (',', ',')]}},
#  {'status': 'UNLABELLED',
#   'data': {'raw': [('Web', 'NNP'),
#     ('Component', 'NNP'),
#     ('APIS', 'NNP'),
#     (':', ':'),
#     (':', ':'),
#     ('Jdbc', 'NN'),
#     (',', ','),
#     ('Servlet', 'NNP'),
#     (',', ','),
#     ('JSP', 'NNP'),
#     ('.', '.')]}},
#  {'status': 'UNLABELLED',
#   'data': {'raw': [('Frameworks', 'NNS'),
#     (':', ':'),
#     ('Spring', 'NN'),
#     ('4', 'CD'),
#     ('&', 'CC'),
#     ('Struts', 'NNP'),
#     ('2', 'CD')]}},
#  {'status': 'UNLABELLED',
#   'data': {'raw': [('ORM', 'NNP'),
#     ('Framework', 'NN'),
#     (':', ':'),
#     ('Hibernate', 'NN')]}},
#  {'status': 'UNLABELLED',
#   'data': {'raw': [('Web', 'NNP'),
#     ('Development', 'NNP'),
#     (':', ':'),
#     ('Html5', 'NNP'),
#     (',', ','),
#     ('CSS3', 'NNP'),
#     (',', ','),
#     ('Java', 'NNP'),
#     ('Script', 'NNP'),
#     (',', ','),
#     ('Ajax', 'NNP'),
#     ('&', 'CC'),
#     ('JQuery', 'NNP'),
#     (',', ','),
#     ('Angular', 'NNP'),
#     ('Js', 'NNP')]}},
#  {'status': 'UNLABELLED',
#   'data': {'raw': [('https', 'NN'),
#     (':', ':'),
#     ('//www.indeed.com/r/Ananya-Chavan/738779ab71971a96', 'JJ'),
#     ('?', '.'),
#     ('isid=rex-download', 'JJ'),
#     ('&', 'CC'),
#     ('ikw=download-top', 'JJ'),
#     ('&', 'CC'),
#     ('co=IN', 'NN')]}},
#  {'status': 'UNLABELLED',
#   'data': {'raw': [('https', 'NN'),
#     (':', ':'),
#     ('//www.indeed.com/r/Ananya-Chavan/738779ab71971a96', 'JJ'),
#     ('?', '.'),
#     ('isid=rex-download', 'JJ'),
#     ('&', 'CC'),
#     ('ikw=download-top', 'JJ'),
#     ('&', 'CC'),
#     ('co=IN', 'NN')]}},
#  {'status': 'UNLABELLED',
#   'data': {'raw': [('Application', 'NN'),
#     ('Servers', 'NNS'),
#     (':', ':'),
#     ('Apache', 'NNP'),
#     ('Tomcat', 'NNP'),
#     (',', ',')]}},
#  {'status': 'UNLABELLED',
#   'data': {'raw': [('IDE', 'NN'),
#     (':', ':'),
#     ('Eclipse', 'NN'),
#     (',', ','),
#     ('Netbeans', 'NNS')]}},
#  {'status': 'UNLABELLED',
#   'data': {'raw': [('Database', 'NN'),
#     (':', ':'),
#     ('Ms-Access', 'JJ'),
#     (',', ','),
#     ('Mysql', 'NNP')]}},
#  {'status': 'UNLABELLED',
#   'data': {'raw': [('Operating', 'VBG'),
#     ('Systems', 'NNPS'),
#     (':', ':'),
#     ('Windows', 'VBZ'),
#     ('7', 'CD'),
#     (',', ','),
#     ('8', 'CD'),
#     (',', ','),
#     ('10', 'CD')]}},
#  {'status': 'UNLABELLED',
#   'data': {'raw': [('FTP', 'NNP'),
#     ('Client', 'NNP'),
#     (':', ':'),
#     ('Filezilla', 'NN')]}},
#  {'status': 'UNLABELLED',
#   'data': {'raw': [('Versioning', 'VBG'),
#     ('Tools', 'NNS'),
#     (':', ':'),
#     ('Git', 'NN')]}},
#  {'status': 'UNLABELLED',
#   'data': {'raw': [('Project', 'NN'), ('Details', 'VBZ'), (':', ':')]}},
#  {'status': 'UNLABELLED',
#   'data': {'raw': [('``', '``'),
#     ('Real', 'JJ'),
#     ('Estate', 'NNP'),
#     ('Application', 'NNP'),
#     ("''", "''"),
#     ('(', '('),
#     ('Client', 'NN'),
#     (':', ':'),
#     ('Global', 'JJ'),
#     ('Realtor', 'NNP'),
#     ('PVT', 'NNP'),
#     ('.', '.'),
#     ('LTD', 'NNP'),
#     ('Pune', 'NNP'),
#     (')', ')')]}},
#  {'status': 'UNLABELLED',
#   'data': {'raw': [('Front-End', 'NN'),
#     (':', ':'),
#     ('Java', 'NNP'),
#     ('(', '('),
#     ('J2EE', 'NNP'),
#     (')', ')'),
#     (',', ','),
#     ('JDBC', 'NNP'),
#     (',', ','),
#     ('Servlet', 'NNP'),
#     (',', ','),
#     ('JSP', 'NNP'),
#     (',', ','),
#     ('Jquery', 'NNP'),
#     ('.', '.')]}},
#  {'status': 'UNLABELLED',
#   'data': {'raw': [('Back', 'RB'),
#     ('end', 'NN'),
#     (':', ':'),
#     ('Mysql', 'NNP'),
#     ('.', '.')]}},
#  {'status': 'UNLABELLED',
#   'data': {'raw': [('Duration', 'NN'),
#     (':', ':'),
#     ('6', 'CD'),
#     ('Month', 'NNP'),
#     ('(', '('),
#     ('Internship', 'NNP'),
#     (')', ')')]}},
#  {'status': 'UNLABELLED',
#   'data': {'raw': [('Company', 'NN'),
#     ('Name', 'NN'),
#     (':', ':'),
#     ('AryanTech', 'NNP'),
#     ('India', 'NNP'),
#     ('Pvt', 'NNP'),
#     ('.', '.'),
#     ('Ltd.', 'NNP'),
#     ('Pune', 'NNP')]}},
#  {'status': 'UNLABELLED',
#   'data': {'raw': [('My', 'PRP$'),
#     ('Role', 'NN'),
#     (':', ':'),
#     ('Developer', 'NNP'),
#     ('as', 'IN'),
#     ('Trainee', 'NNP'),
#     ('.', '.')]}},
#  {'status': 'UNLABELLED',
#   'data': {'raw': [('Module', 'NN'),
#     (':', ':'),
#     ('Module', 'NN'),
#     ('4', 'CD'),
#     ('.', '.')]}},
#  {'status': 'UNLABELLED',
#   'data': {'raw': [('Description', 'NN'),
#     (':', ':'),
#     ('Developed', 'VBN'),
#     ('as', 'IN'),
#     ('a', 'DT'),
#     ('MCA', 'NNP'),
#     ('Final', 'NNP'),
#     ('SEM', 'NNP'),
#     ('Project', 'NNP'),
#     ('for', 'IN')]}},
#  {'status': 'UNLABELLED',
#   'data': {'raw': [('``', '``'),
#     ('Global', 'JJ'),
#     ('Realtors', 'NNPS'),
#     ('PVT.LTD', 'NNP'),
#     (',', ','),
#     ('Hinjewadi', 'NNP'),
#     (',', ','),
#     ('Pune', 'NNP'),
#     ('.', '.'),
#     ("''", "''")]}},
#  {'status': 'UNLABELLED',
#   'data': {'raw': [('The', 'DT'),
#     ('Real', 'JJ'),
#     ('Estate', 'NNP'),
#     ('Web', 'NNP'),
#     ('Application', 'NNP'),
#     ('is', 'VBZ'),
#     ('an', 'DT'),
#     ('interactive', 'JJ'),
#     (',', ','),
#     ('effective', 'JJ'),
#     ('and', 'CC'),
#     ('revenue-generating', 'JJ'),
#     ('website', 'NN')]}},
#  {'status': 'UNLABELLED',
#   'data': {'raw': [('designed', 'VBN'),
#     ('for', 'IN'),
#     ('the', 'DT'),
#     ('Real', 'JJ'),
#     ('Estate', 'NNP'),
#     ('Industry', 'NNP'),
#     ('.', '.'),
#     ('The', 'DT'),
#     ('main', 'JJ'),
#     ('objective', 'NN'),
#     ('of', 'IN'),
#     ('this', 'DT'),
#     ('application', 'NN'),
#     ('is', 'VBZ'),
#     ('to', 'TO'),
#     ('help', 'VB'),
#     ('the', 'DT'),
#     ('Real', 'JJ')]}},
#  {'status': 'UNLABELLED',
#   'data': {'raw': [('Estate', 'NNP'),
#     ('Company', 'NNP'),
#     ('to', 'TO'),
#     ('display', 'VB'),
#     ('unlimited', 'JJ'),
#     ('number', 'NN'),
#     ('of', 'IN'),
#     ('property', 'NN'),
#     ('listings', 'NNS'),
#     ('on', 'IN'),
#     ('the', 'DT'),
#     ('website', 'NN'),
#     ('.', '.')]}},
#  {'status': 'UNLABELLED',
#   'data': {'raw': [('``', '``'),
#     ('Beauty', 'NNP'),
#     ('Parlor', 'NNP'),
#     ('Management', 'NNP'),
#     ('System', 'NNP'),
#     ("''", "''"),
#     ('(', '('),
#     ('B.Sc', 'NNP'),
#     ('.', '.'),
#     ('(', '('),
#     ('Com.Sci', 'NNP'),
#     ('.', '.'),
#     (')', ')'),
#     (')', ')')]}},
#  {'status': 'UNLABELLED',
#   'data': {'raw': [('Tool', 'NN'), (':', ':'), ('VB', '$'), ('6.0', 'CD')]}},
#  {'status': 'UNLABELLED',
#   'data': {'raw': [('Language', 'NN'), (':', ':'), ('VB', 'NN')]}},
#  {'status': 'UNLABELLED',
#   'data': {'raw': [('Database', 'NN'), (':', ':'), ('MS-Access', 'JJ')]}},
#  {'status': 'UNLABELLED',
#   'data': {'raw': [('Operating', 'NN'),
#     ('System', 'NN'),
#     (':', ':'),
#     ('Windows', 'VBZ'),
#     ('XP', 'NN')]}},
#  {'status': 'UNLABELLED',
#   'data': {'raw': [('The', 'DT'),
#     ('Beauty', 'NNP'),
#     ('Parlor', 'NNP'),
#     ('Management', 'NNP'),
#     ('System', 'NNP'),
#     ('is', 'VBZ'),
#     ('an', 'DT'),
#     ('easy', 'JJ'),
#     ('and', 'CC'),
#     ('effective', 'JJ'),
#     ('system', 'NN'),
#     ('to', 'TO'),
#     ('use', 'VB'),
#     ('.', '.'),
#     ('The', 'DT'),
#     ('main', 'JJ'),
#     ('features', 'NNS')]}},
#  {'status': 'UNLABELLED',
#   'data': {'raw': [('of', 'IN'),
#     ('this', 'DT'),
#     ('system', 'NN'),
#     ('are', 'VBP'),
#     ('to', 'TO'),
#     ('avoid', 'VB'),
#     ('manual', 'JJ'),
#     ('work', 'NN'),
#     ('and', 'CC'),
#     ('keep', 'VB'),
#     ('storing', 'VBG'),
#     ('all', 'DT'),
#     ('appointments', 'NNS'),
#     ('of', 'IN'),
#     ('customers', 'NNS'),
#     ('.', '.')]}},
#  {'status': 'UNLABELLED',
#   'data': {'raw': [('``', '``'),
#     ('Web', 'NNP'),
#     ('Designing', 'NNP'),
#     ('Project', 'NNP'),
#     ('(', '('),
#     ('Reptiles.com', 'NNP'),
#     (')', ')'),
#     ('``', '``'),
#     ('(', '('),
#     ('B.Sc', 'NNP'),
#     ('.', '.'),
#     ('(', '('),
#     ('Com.Sci', 'NNP'),
#     ('.', '.'),
#     (')', ')'),
#     (')', ')')]}},
#  {'status': 'UNLABELLED',
#   'data': {'raw': [('Language', 'NN'),
#     (':', ':'),
#     ('HTML', 'NNP'),
#     ('and', 'CC'),
#     ('ASP', 'NNP')]}},
#  {'status': 'UNLABELLED',
#   'data': {'raw': [('Tool', 'NN'),
#     (':', ':'),
#     ('Dreamweaver', 'NN'),
#     ('8.0', 'CD')]}},
#  {'status': 'UNLABELLED',
#   'data': {'raw': [('Database', 'NN'), (':', ':'), ('MS-Access', 'JJ')]}},
#  {'status': 'UNLABELLED',
#   'data': {'raw': [('Operating', 'NN'),
#     ('System', 'NN'),
#     (':', ':'),
#     ('Windows', 'VBZ'),
#     ('XP', 'NN')]}},
#  {'status': 'UNLABELLED',
#   'data': {'raw': [('The', 'DT'),
#     ('Reptiles.com', 'NNP'),
#     ('is', 'VBZ'),
#     ('a', 'DT'),
#     ('simple', 'JJ'),
#     ('informative', 'JJ'),
#     ('site', 'NN'),
#     ('.', '.'),
#     ('The', 'DT'),
#     ('main', 'JJ'),
#     ('features', 'NNS'),
#     ('of', 'IN'),
#     ('this', 'DT'),
#     ('system', 'NN'),
#     ('are', 'VBP'),
#     ('to', 'TO'),
#     ('give', 'VB'),
#     ('all', 'DT')]}},
#  {'status': 'UNLABELLED',
#   'data': {'raw': [('information', 'NN'),
#     ('of', 'IN'),
#     ('Snakes', 'NNP'),
#     ('.', '.')]}}]

# %%
nertagger.start_server(port=5053)
# Out:
#  * Serving Flask app "NERD.ner" (lazy loading)
#  * Environment: production
#    WARNING: This is a development server. Do not use it in a production deployment.
#    Use a production WSGI server instead.
#  * Debug mode: off
#  * Running on http://127.0.0.1:5053/ (Press CTRL+C to quit)
# 127.0.0.1 - - [20/Aug/2020 19:11:37] "POST /save_example HTTP/1.1" 200 -

# %%
nertagger.ntagger.dataset[52]
# Out:
# {'status': 'LABELLED',
#  'data': {'raw': [('PERSONALLITY', 'NNP', 'O'),
#    ('TRAITS', 'NNP', 'O'),
#    (':', ':', 'O')],
#   'features': [{'bias': 1.0,
#     'word.lower()': 'personallity',
#     'word[-3:]': 'ITY',
#     'word[-2:]': 'TY',
#     'word.isupper()': True,
#     'word.istitle()': False,
#     'word.isdigit()': False,
#     'word.is_alphanum': 'ALPHA_UPPER',
#     'postag': 'NNP',
#     'BOS': True,
#     '+1:word.lower()': 'traits',
#     '+1:word[-3:]': 'ITS',
#     '+1:word[-2:]': 'TS',
#     '+1:word.istitle()': False,
#     '+1:word.isupper()': True,
#     '+1:postag': 'NNP',
#     '+1:word.is_alphanum': 'ALPHA_UPPER',
#     '+2:word.lower()': ':',
#     '+2:word[-3:]': ':',
#     '+2:word[-2:]': ':',
#     '+2:word.istitle()': False,
#     '+2:word.isupper()': False,
#     '+2:postag': ':',
#     '+2:word.is_alphanum': 'ALPHA_NUM'},
#    {'bias': 1.0,
#     'word.lower()': 'traits',
#     'word[-3:]': 'ITS',
#     'word[-2:]': 'TS',
#     'word.isupper()': True,
#     'word.istitle()': False,
#     'word.isdigit()': False,
#     'word.is_alphanum': 'ALPHA_UPPER',
#     'postag': 'NNP',
#     '-1:word.lower()': 'personallity',
#     '-1:word[-3:]': 'ITY',
#     '-1:word[-2:]': 'TY',
#     '-1:word.istitle()': False,
#     '-1:word.isupper()': True,
#     '-1:postag': 'NNP',
#     '-1:word.is_alphanum': 'ALPHA_UPPER',
#     '+1:word.lower()': ':',
#     '+1:word[-3:]': ':',
#     '+1:word[-2:]': ':',
#     '+1:word.istitle()': False,
#     '+1:word.isupper()': False,
#     '+1:postag': ':',
#     '+1:word.is_alphanum': 'ALPHA_NUM'},
#    {'bias': 1.0,
#     'word.lower()': ':',
#     'word[-3:]': ':',
#     'word[-2:]': ':',
#     'word.isupper()': False,
#     'word.istitle()': False,
#     'word.isdigit()': False,
#     'word.is_alphanum': 'ALPHA_NUM',
#     'postag': ':',
#     '-1:word.lower()': 'traits',
#     '-1:word[-3:]': 'ITS',
#     '-1:word[-2:]': 'TS',
#     '-1:word.istitle()': False,
#     '-1:word.isupper()': True,
#     '-1:postag': 'NNP',
#     '-1:word.is_alphanum': 'ALPHA_UPPER',
#     '-2:word.lower()': 'personallity',
#     '-2:word[-3:]': 'ITY',
#     '-2:word[-2:]': 'TY',
#     '-2:word.istitle()': False,
#     '-2:word.isupper()': True,
#     '-2:postag': 'NNP',
#     '-2:word.is_alphanum': 'ALPHA_UPPER',
#     'EOS': True}]}}

# %%
len([ex for ex in nertagger.ntagger.dataset if ex['status'] == 'LABELLED'])
# Out:
# 3
